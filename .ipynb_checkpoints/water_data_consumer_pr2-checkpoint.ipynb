# %%
from kafka import KafkaConsumer
import json
import matplotlib.pyplot as plt
import time

# %%
# Initialize data storage for plotting
timestamps = []
water_temperatures = []
ph_levels = []
turbidities = []
dissolved_oxygen_levels = []

# %%
# Kafka configuration
def initialize_consumer():
    kafka_topic = "water_quality"
    kafka_bootstrap_servers = ["localhost:9092"]

    # Create Kafka consumer
    consumer = KafkaConsumer(
        kafka_topic,
        bootstrap_servers=kafka_bootstrap_servers,
        value_deserializer=lambda m: json.loads(m.decode('utf-8')),
        auto_offset_reset='latest',
        enable_auto_commit=True
    )
    return consumer

# %%
# Receive all published messages and update plot
def update_plot(consumer):
    try:
        for message in consumer:
            # Parse the message
            sensor_data = message.value
            print(f"Received: {sensor_data}")

            # Update data storage
            timestamps.append(sensor_data['timestamp'])
            water_temperatures.append(sensor_data['water_temperature'])
            ph_levels.append(sensor_data['ph_level'])
            turbidities.append(sensor_data['turbidity'])
            dissolved_oxygen_levels.append(sensor_data['dissolved_oxygen'])

            # Keep only the last 100 entries for plotting
            if len(timestamps) > 100:
                timestamps.pop(0)
                water_temperatures.pop(0)
                ph_levels.pop(0)
                turbidities.pop(0)
                dissolved_oxygen_levels.pop(0)

            # Clear the current axes and redraw the plots
            plt.figure(figsize=(10, 8))

            plt.subplot(2, 2, 1)
            plt.plot(timestamps, water_temperatures, label="Water Temperature", color="blue")
            plt.title("Water Temperature")
            plt.ylabel("°C")

            plt.subplot(2, 2, 2)
            plt.plot(timestamps, ph_levels, label="pH Level", color="green")
            plt.title("pH Level")
            plt.ylabel("pH")

            plt.subplot(2, 2, 3)
            plt.plot(timestamps, turbidities, label="Turbidity", color="orange")
            plt.title("Turbidity")
            plt.ylabel("NTU")

            plt.subplot(2, 2, 4)
            plt.plot(timestamps, dissolved_oxygen_levels, label="Dissolved Oxygen", color="red")
            plt.title("Dissolved Oxygen")
            plt.ylabel("mg/L")

            plt.tight_layout()

            # Save the plot as an image
            plt.savefig(f"water_quality_plot.png")
            plt.close()

            break  # Process one message at a time
    except KeyboardInterrupt:
        print("Stopped consuming messages.")
        consumer.close()

# %%
consumer = initialize_consumer()
print("Subscribed to Kafka topic 'water_quality'.")

try:
    while True:
        update_plot(consumer)
except KeyboardInterrupt:
    print("Stopped visualization.")
    consumer.close()
# Out:
# Subscribed to Kafka topic 'water_quality'.
# ---------------------------------------------------------------------------
# NoOffsetForPartitionError                 Traceback (most recent call last)
# Cell In[5], line 6
#       4 try:
#       5     while True:
# ----> 6         update_plot(consumer)
#       7 except KeyboardInterrupt:
#       8     print("Stopped visualization.")
#
# Cell In[4], line 4, in update_plot(consumer)
#       2 def update_plot(consumer):
#       3     try:
# ----> 4         for message in consumer:
#       5             # Parse the message
#       6             sensor_data = message.value
#       7             print(f"Received: {sensor_data}")
#
# File /usr/local/lib/python3.10/dist-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File /usr/local/lib/python3.10/dist-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File /usr/local/lib/python3.10/dist-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File /usr/local/lib/python3.10/dist-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File /usr/local/lib/python3.10/dist-packages/kafka/consumer/group.py:680, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     677 # Fetch positions if we have partitions we're subscribed to that we
#     678 # don't know the offset for
#     679 if not self._subscription.has_all_fetch_positions():
# --> 680     self._update_fetch_positions(self._subscription.missing_fetch_positions())
#     682 # If data is available already, e.g. from a previous network client
#     683 # poll() call to commit, then just return it immediately
#     684 records, partial = self._fetcher.fetched_records(max_records, update_offsets=update_offsets)
#
# File /usr/local/lib/python3.10/dist-packages/kafka/consumer/group.py:1112, in KafkaConsumer._update_fetch_positions(self, partitions)
#    1109     self._coordinator.refresh_committed_offsets_if_needed()
#    1111 # Then, do any offset lookups in case some positions are not known
# -> 1112 self._fetcher.update_fetch_positions(partitions)
#
# File /usr/local/lib/python3.10/dist-packages/kafka/consumer/fetcher.py:186, in Fetcher.update_fetch_positions(self, partitions)
#     182 elif self._subscriptions.assignment[tp].committed is None:
#     183     # there's no committed position, so we need to reset with the
#     184     # default strategy
#     185     self._subscriptions.need_offset_reset(tp)
# --> 186     self._reset_offset(tp)
#     187 else:
#     188     committed = self._subscriptions.assignment[tp].committed.offset
#
# File /usr/local/lib/python3.10/dist-packages/kafka/consumer/fetcher.py:233, in Fetcher._reset_offset(self, partition)
#     231     strategy = 'latest'
#     232 else:
# --> 233     raise NoOffsetForPartitionError(partition)
#     235 log.debug("Resetting offset for partition %s to %s offset.",
#     236           partition, strategy)
#     237 offsets = self._retrieve_offsets({partition: timestamp})
#
# NoOffsetForPartitionError: NoOffsetForPartitionError: TopicPartition(topic='water_quality', partition=0)

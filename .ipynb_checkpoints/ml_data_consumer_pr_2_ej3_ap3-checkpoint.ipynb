# %%
import json
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
from kafka import KafkaConsumer

KAFKA_BOOTSTRAP_SERVERS = ["localhost:9092"]
INFERENCE_TOPIC = "ml_predictions_final"
GROUP_ID        = "inference_dashboard"
MAX_POINTS      = 200
SAVE_EVERY      = 1

timestamps       = []
predictions      = []
prob_aeration    = []
prob_no_aeration = []

consumer = KafkaConsumer(
    INFERENCE_TOPIC,
    bootstrap_servers=KAFKA_BOOTSTRAP_SERVERS,
    value_deserializer=lambda m: json.loads(m.decode("utf-8")),
    auto_offset_reset="latest",
    enable_auto_commit=True,
    group_id=GROUP_ID,
)

from collections import defaultdict

# buffers por sensor
buffers = defaultdict(lambda: {
    "timestamps": [],
    "preds": [],
    "p0": [],
    "p1": [],
    "ts_pred1": [],  
    "conf_pred1": [],
    "ts_pred0": [],  
    "conf_pred0": [],
})

print(f"Subscribed to Kafka topic '{INFERENCE_TOPIC}'.\n")

msg_count = 0

try:
    for message in consumer:
        sensor_id = message.key if message.key else message.value.get("sensor_id", "unknown_sensor")
        sensor_data = message.value
        print(f"Received sensor={sensor_id}: {sensor_data}")

        ts = sensor_data["timestamp"]
        pred = int(sensor_data["prediction"])
        p0 = float(sensor_data["prob_class0"])
        p1 = float(sensor_data["prob_class1"])

        # buffer del sensor
        buf = buffers[sensor_id]

        # Update data storage
        buf["timestamps"].append(ts)
        buf["preds"].append(pred)
        buf["p0"].append(p0)
        buf["p1"].append(p1)

        # series filtradas por clase escogida
        if pred == 1:
            buf["ts_pred1"].append(ts)
            buf["conf_pred1"].append(p1)
        else:
            buf["ts_pred0"].append(ts)
            buf["conf_pred0"].append(p0)

        # Keep only the last 100 entries
        if len(buf["timestamps"]) > 100:
            min_ts = buf["timestamps"][-100]
            buf["timestamps"] = buf["timestamps"][-100:]
            buf["preds"] = buf["preds"][-100:]
            buf["p0"] = buf["p0"][-100:]
            buf["p1"] = buf["p1"][-100:]

            while buf["ts_pred1"] and buf["ts_pred1"][0] < min_ts:
                buf["ts_pred1"].pop(0); buf["conf_pred1"].pop(0)
            while buf["ts_pred0"] and buf["ts_pred0"][0] < min_ts:
                buf["ts_pred0"].pop(0); buf["conf_pred0"].pop(0)

        # Plot (2x2 con 3 paneles como la referencia)
        plt.figure(figsize=(10, 8))

        plt.subplot(2, 2, 1)
        plt.plot(buf["timestamps"], buf["preds"])
        plt.title("Aeration")
        plt.ylabel("Aeration produced")
        plt.ylim(-0.05, 1.05)

        plt.subplot(2, 2, 2)
        plt.plot(buf["ts_pred1"], buf["conf_pred1"], color="green")
        plt.title("Aeration confidence")
        plt.ylabel("Confidence")
        plt.ylim(0.0, 1.05)

        plt.subplot(2, 2, 3)
        plt.plot(buf["ts_pred0"], buf["conf_pred0"], color="orange")
        plt.title("Non aeration confidence")
        plt.ylabel("Confidence")
        plt.ylim(0.0, 1.05)

        plt.subplot(2, 2, 4)
        plt.axis("off")

        plt.tight_layout()
        plt.savefig(f"Images/Parte3/aeration_inference_{sensor_id.decode('utf-8')}.png")
        plt.close()


except KeyboardInterrupt:
    print("Stopped consuming messages.")
    consumer.close()
# Out:
# Subscribed to Kafka topic 'ml_predictions_final'.
#
# Received sensor=b'sensor_002': {'sensor_id': 'sensor_002', 'timestamp': 1772385471, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.33, 'ph_level': 8.06, 'turbidity': 48.54, 'dissolved_oxygen': 11.71}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385471, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.76, 'ph_level': 8.56, 'turbidity': 7.29, 'dissolved_oxygen': 8.29}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385471, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.88, 'ph_level': 7.94, 'turbidity': 37.51, 'dissolved_oxygen': 5.59}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385471, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.13, 'ph_level': 8.19, 'turbidity': 47.51, 'dissolved_oxygen': 5.36}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385473, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.07, 'ph_level': 7.92, 'turbidity': 11.69, 'dissolved_oxygen': 6.05}
# Received sensor=b'sensor_001': {'sensor_id': 'sensor_001', 'timestamp': 1772385473, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.07, 'ph_level': 8.77, 'turbidity': 27.67, 'dissolved_oxygen': 6.02}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385473, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.87, 'ph_level': 7.86, 'turbidity': 16.01, 'dissolved_oxygen': 7.75}
# Received sensor=b'sensor_002': {'sensor_id': 'sensor_002', 'timestamp': 1772385473, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.24, 'ph_level': 8.54, 'turbidity': 18.75, 'dissolved_oxygen': 11.87}
# Received sensor=b'sensor_004': {'sensor_id': 'sensor_004', 'timestamp': 1772385473, 'prediction': 0, 'prob_class0': 0.9, 'prob_class1': 0.1, 'water_temperature': 29.65, 'ph_level': 8.62, 'turbidity': 38.42, 'dissolved_oxygen': 7.56}
# Received sensor=b'sensor_006': {'sensor_id': 'sensor_006', 'timestamp': 1772385473, 'prediction': 1, 'prob_class0': 0.2, 'prob_class1': 0.8, 'water_temperature': 28.35, 'ph_level': 8.82, 'turbidity': 47.11, 'dissolved_oxygen': 7.3}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385473, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.46, 'ph_level': 8.35, 'turbidity': 23.67, 'dissolved_oxygen': 11.02}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385473, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.39, 'ph_level': 8.0, 'turbidity': 31.83, 'dissolved_oxygen': 9.09}
# Received sensor=b'sensor_005': {'sensor_id': 'sensor_005', 'timestamp': 1772385473, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.3, 'ph_level': 8.73, 'turbidity': 23.18, 'dissolved_oxygen': 10.49}
# Received sensor=b'sensor_008': {'sensor_id': 'sensor_008', 'timestamp': 1772385473, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.98, 'ph_level': 7.92, 'turbidity': 29.43, 'dissolved_oxygen': 6.67}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385475, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.12, 'ph_level': 8.68, 'turbidity': 27.29, 'dissolved_oxygen': 9.56}
# Received sensor=b'sensor_001': {'sensor_id': 'sensor_001', 'timestamp': 1772385475, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.93, 'ph_level': 8.24, 'turbidity': 14.78, 'dissolved_oxygen': 11.52}
# Received sensor=b'sensor_004': {'sensor_id': 'sensor_004', 'timestamp': 1772385475, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.26, 'ph_level': 8.01, 'turbidity': 46.53, 'dissolved_oxygen': 11.63}
# Received sensor=b'sensor_005': {'sensor_id': 'sensor_005', 'timestamp': 1772385475, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.99, 'ph_level': 8.78, 'turbidity': 31.76, 'dissolved_oxygen': 6.45}
# Received sensor=b'sensor_006': {'sensor_id': 'sensor_006', 'timestamp': 1772385475, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.35, 'ph_level': 8.26, 'turbidity': 14.31, 'dissolved_oxygen': 11.61}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385475, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.4, 'ph_level': 8.44, 'turbidity': 40.43, 'dissolved_oxygen': 6.97}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385475, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.47, 'ph_level': 8.42, 'turbidity': 38.38, 'dissolved_oxygen': 8.98}
# Received sensor=b'sensor_002': {'sensor_id': 'sensor_002', 'timestamp': 1772385475, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.0, 'ph_level': 8.12, 'turbidity': 21.46, 'dissolved_oxygen': 10.83}
# Received sensor=b'sensor_008': {'sensor_id': 'sensor_008', 'timestamp': 1772385475, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.98, 'ph_level': 8.62, 'turbidity': 40.52, 'dissolved_oxygen': 9.02}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385475, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.24, 'ph_level': 8.33, 'turbidity': 19.81, 'dissolved_oxygen': 9.36}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385477, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.36, 'ph_level': 8.58, 'turbidity': 29.25, 'dissolved_oxygen': 11.66}
# Received sensor=b'sensor_002': {'sensor_id': 'sensor_002', 'timestamp': 1772385477, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.32, 'ph_level': 8.25, 'turbidity': 28.9, 'dissolved_oxygen': 10.77}
# Received sensor=b'sensor_001': {'sensor_id': 'sensor_001', 'timestamp': 1772385477, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.58, 'ph_level': 8.75, 'turbidity': 43.76, 'dissolved_oxygen': 8.77}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385477, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.29, 'ph_level': 8.32, 'turbidity': 30.38, 'dissolved_oxygen': 6.03}
# Received sensor=b'sensor_004': {'sensor_id': 'sensor_004', 'timestamp': 1772385477, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.81, 'ph_level': 7.99, 'turbidity': 5.44, 'dissolved_oxygen': 10.54}
# Received sensor=b'sensor_006': {'sensor_id': 'sensor_006', 'timestamp': 1772385477, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.13, 'ph_level': 8.28, 'turbidity': 43.22, 'dissolved_oxygen': 9.21}
# Received sensor=b'sensor_005': {'sensor_id': 'sensor_005', 'timestamp': 1772385477, 'prediction': 1, 'prob_class0': 0.1, 'prob_class1': 0.9, 'water_temperature': 28.22, 'ph_level': 8.65, 'turbidity': 28.83, 'dissolved_oxygen': 7.5}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385477, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.35, 'ph_level': 8.53, 'turbidity': 32.67, 'dissolved_oxygen': 5.48}
# Received sensor=b'sensor_008': {'sensor_id': 'sensor_008', 'timestamp': 1772385477, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.43, 'ph_level': 8.85, 'turbidity': 41.87, 'dissolved_oxygen': 11.98}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385477, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.3, 'ph_level': 8.19, 'turbidity': 18.86, 'dissolved_oxygen': 11.46}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385479, 'prediction': 1, 'prob_class0': 0.1, 'prob_class1': 0.9, 'water_temperature': 28.56, 'ph_level': 8.57, 'turbidity': 23.71, 'dissolved_oxygen': 6.24}
# Received sensor=b'sensor_002': {'sensor_id': 'sensor_002', 'timestamp': 1772385479, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.85, 'ph_level': 8.6, 'turbidity': 12.37, 'dissolved_oxygen': 9.12}
# Received sensor=b'sensor_001': {'sensor_id': 'sensor_001', 'timestamp': 1772385479, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.86, 'ph_level': 8.43, 'turbidity': 30.82, 'dissolved_oxygen': 10.48}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385479, 'prediction': 0, 'prob_class0': 0.6, 'prob_class1': 0.4, 'water_temperature': 28.7, 'ph_level': 8.18, 'turbidity': 29.64, 'dissolved_oxygen': 8.37}
# Received sensor=b'sensor_004': {'sensor_id': 'sensor_004', 'timestamp': 1772385479, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.27, 'ph_level': 8.71, 'turbidity': 5.83, 'dissolved_oxygen': 9.37}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385479, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.75, 'ph_level': 8.16, 'turbidity': 42.23, 'dissolved_oxygen': 9.98}
# Received sensor=b'sensor_006': {'sensor_id': 'sensor_006', 'timestamp': 1772385479, 'prediction': 0, 'prob_class0': 0.7, 'prob_class1': 0.3, 'water_temperature': 29.55, 'ph_level': 8.43, 'turbidity': 16.53, 'dissolved_oxygen': 7.99}
# Received sensor=b'sensor_005': {'sensor_id': 'sensor_005', 'timestamp': 1772385479, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.31, 'ph_level': 7.96, 'turbidity': 11.73, 'dissolved_oxygen': 5.08}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385479, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.97, 'ph_level': 8.4, 'turbidity': 27.3, 'dissolved_oxygen': 6.39}
# Received sensor=b'sensor_008': {'sensor_id': 'sensor_008', 'timestamp': 1772385479, 'prediction': 0, 'prob_class0': 0.7, 'prob_class1': 0.3, 'water_temperature': 29.7, 'ph_level': 8.78, 'turbidity': 30.67, 'dissolved_oxygen': 7.81}
# Received sensor=b'sensor_001': {'sensor_id': 'sensor_001', 'timestamp': 1772385481, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.86, 'ph_level': 7.98, 'turbidity': 28.27, 'dissolved_oxygen': 9.37}
# Received sensor=b'sensor_002': {'sensor_id': 'sensor_002', 'timestamp': 1772385481, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.28, 'ph_level': 8.15, 'turbidity': 5.06, 'dissolved_oxygen': 10.38}
# Received sensor=b'sensor_004': {'sensor_id': 'sensor_004', 'timestamp': 1772385481, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.57, 'ph_level': 7.97, 'turbidity': 31.15, 'dissolved_oxygen': 9.99}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385481, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.05, 'ph_level': 8.22, 'turbidity': 36.15, 'dissolved_oxygen': 11.14}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385481, 'prediction': 0, 'prob_class0': 0.9, 'prob_class1': 0.1, 'water_temperature': 28.55, 'ph_level': 8.1, 'turbidity': 9.98, 'dissolved_oxygen': 8.85}
# Received sensor=b'sensor_005': {'sensor_id': 'sensor_005', 'timestamp': 1772385481, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.19, 'ph_level': 8.02, 'turbidity': 22.98, 'dissolved_oxygen': 11.45}
# Received sensor=b'sensor_006': {'sensor_id': 'sensor_006', 'timestamp': 1772385481, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.55, 'ph_level': 8.74, 'turbidity': 33.54, 'dissolved_oxygen': 8.76}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385481, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.78, 'ph_level': 8.29, 'turbidity': 47.38, 'dissolved_oxygen': 5.24}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385481, 'prediction': 1, 'prob_class0': 0.2, 'prob_class1': 0.8, 'water_temperature': 28.24, 'ph_level': 8.17, 'turbidity': 31.34, 'dissolved_oxygen': 7.7}
# Received sensor=b'sensor_008': {'sensor_id': 'sensor_008', 'timestamp': 1772385481, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.2, 'ph_level': 8.67, 'turbidity': 17.39, 'dissolved_oxygen': 11.03}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385483, 'prediction': 1, 'prob_class0': 0.2, 'prob_class1': 0.8, 'water_temperature': 29.21, 'ph_level': 8.27, 'turbidity': 13.42, 'dissolved_oxygen': 7.31}
# Received sensor=b'sensor_001': {'sensor_id': 'sensor_001', 'timestamp': 1772385483, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.86, 'ph_level': 8.53, 'turbidity': 23.73, 'dissolved_oxygen': 9.84}
# Received sensor=b'sensor_002': {'sensor_id': 'sensor_002', 'timestamp': 1772385483, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.65, 'ph_level': 8.46, 'turbidity': 36.97, 'dissolved_oxygen': 9.64}
# Received sensor=b'sensor_005': {'sensor_id': 'sensor_005', 'timestamp': 1772385483, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.31, 'ph_level': 8.63, 'turbidity': 35.63, 'dissolved_oxygen': 9.2}
# Received sensor=b'sensor_004': {'sensor_id': 'sensor_004', 'timestamp': 1772385483, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.46, 'ph_level': 7.88, 'turbidity': 8.66, 'dissolved_oxygen': 9.78}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385483, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.6, 'ph_level': 8.43, 'turbidity': 48.87, 'dissolved_oxygen': 10.53}
# Received sensor=b'sensor_006': {'sensor_id': 'sensor_006', 'timestamp': 1772385483, 'prediction': 0, 'prob_class0': 0.9, 'prob_class1': 0.1, 'water_temperature': 29.45, 'ph_level': 8.71, 'turbidity': 19.87, 'dissolved_oxygen': 8.09}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385483, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.17, 'ph_level': 8.49, 'turbidity': 39.93, 'dissolved_oxygen': 9.21}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385483, 'prediction': 0, 'prob_class0': 0.7, 'prob_class1': 0.3, 'water_temperature': 29.78, 'ph_level': 8.16, 'turbidity': 42.58, 'dissolved_oxygen': 7.03}
# Received sensor=b'sensor_008': {'sensor_id': 'sensor_008', 'timestamp': 1772385483, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.76, 'ph_level': 8.65, 'turbidity': 20.6, 'dissolved_oxygen': 6.73}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385485, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.23, 'ph_level': 8.27, 'turbidity': 26.52, 'dissolved_oxygen': 9.4}
# Received sensor=b'sensor_004': {'sensor_id': 'sensor_004', 'timestamp': 1772385485, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.49, 'ph_level': 7.9, 'turbidity': 49.13, 'dissolved_oxygen': 9.68}
# Received sensor=b'sensor_002': {'sensor_id': 'sensor_002', 'timestamp': 1772385485, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.69, 'ph_level': 8.55, 'turbidity': 25.16, 'dissolved_oxygen': 5.43}
# Received sensor=b'sensor_005': {'sensor_id': 'sensor_005', 'timestamp': 1772385485, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.61, 'ph_level': 8.65, 'turbidity': 22.28, 'dissolved_oxygen': 11.23}
# Received sensor=b'sensor_001': {'sensor_id': 'sensor_001', 'timestamp': 1772385485, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 30.03, 'ph_level': 8.06, 'turbidity': 9.04, 'dissolved_oxygen': 10.26}
# Received sensor=b'sensor_006': {'sensor_id': 'sensor_006', 'timestamp': 1772385485, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.62, 'ph_level': 8.57, 'turbidity': 17.82, 'dissolved_oxygen': 8.74}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385485, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.58, 'ph_level': 8.07, 'turbidity': 34.5, 'dissolved_oxygen': 8.97}
# Received sensor=b'sensor_008': {'sensor_id': 'sensor_008', 'timestamp': 1772385485, 'prediction': 1, 'prob_class0': 0.1, 'prob_class1': 0.9, 'water_temperature': 29.27, 'ph_level': 8.68, 'turbidity': 22.35, 'dissolved_oxygen': 7.73}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385485, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.83, 'ph_level': 7.98, 'turbidity': 8.64, 'dissolved_oxygen': 11.78}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385485, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.75, 'ph_level': 8.42, 'turbidity': 5.11, 'dissolved_oxygen': 11.38}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385487, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.39, 'ph_level': 8.74, 'turbidity': 31.47, 'dissolved_oxygen': 11.03}
# Received sensor=b'sensor_001': {'sensor_id': 'sensor_001', 'timestamp': 1772385487, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.61, 'ph_level': 8.82, 'turbidity': 32.23, 'dissolved_oxygen': 8.44}
# Received sensor=b'sensor_002': {'sensor_id': 'sensor_002', 'timestamp': 1772385487, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.04, 'ph_level': 8.36, 'turbidity': 21.16, 'dissolved_oxygen': 6.95}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385487, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.44, 'ph_level': 8.65, 'turbidity': 14.8, 'dissolved_oxygen': 6.14}
# Received sensor=b'sensor_004': {'sensor_id': 'sensor_004', 'timestamp': 1772385487, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.05, 'ph_level': 8.64, 'turbidity': 44.74, 'dissolved_oxygen': 11.9}
# Received sensor=b'sensor_006': {'sensor_id': 'sensor_006', 'timestamp': 1772385487, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.75, 'ph_level': 8.59, 'turbidity': 33.72, 'dissolved_oxygen': 6.08}
# Received sensor=b'sensor_005': {'sensor_id': 'sensor_005', 'timestamp': 1772385487, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.12, 'ph_level': 8.58, 'turbidity': 27.25, 'dissolved_oxygen': 8.21}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385487, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.97, 'ph_level': 7.96, 'turbidity': 24.38, 'dissolved_oxygen': 9.55}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385487, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.05, 'ph_level': 7.94, 'turbidity': 39.5, 'dissolved_oxygen': 11.94}
# Received sensor=b'sensor_008': {'sensor_id': 'sensor_008', 'timestamp': 1772385487, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.82, 'ph_level': 7.95, 'turbidity': 36.74, 'dissolved_oxygen': 7.39}
# Received sensor=b'sensor_002': {'sensor_id': 'sensor_002', 'timestamp': 1772385489, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.13, 'ph_level': 8.82, 'turbidity': 19.17, 'dissolved_oxygen': 6.35}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385489, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.6, 'ph_level': 8.29, 'turbidity': 14.78, 'dissolved_oxygen': 9.44}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385489, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.72, 'ph_level': 8.11, 'turbidity': 13.47, 'dissolved_oxygen': 6.1}
# Received sensor=b'sensor_001': {'sensor_id': 'sensor_001', 'timestamp': 1772385489, 'prediction': 0, 'prob_class0': 0.9, 'prob_class1': 0.1, 'water_temperature': 28.61, 'ph_level': 8.82, 'turbidity': 38.78, 'dissolved_oxygen': 11.79}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385489, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.27, 'ph_level': 8.49, 'turbidity': 34.84, 'dissolved_oxygen': 11.34}
# Received sensor=b'sensor_006': {'sensor_id': 'sensor_006', 'timestamp': 1772385489, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.9, 'ph_level': 8.52, 'turbidity': 32.97, 'dissolved_oxygen': 8.15}
# Received sensor=b'sensor_004': {'sensor_id': 'sensor_004', 'timestamp': 1772385489, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.74, 'ph_level': 8.41, 'turbidity': 17.39, 'dissolved_oxygen': 9.78}
# Received sensor=b'sensor_005': {'sensor_id': 'sensor_005', 'timestamp': 1772385489, 'prediction': 0, 'prob_class0': 0.9, 'prob_class1': 0.1, 'water_temperature': 28.45, 'ph_level': 8.28, 'turbidity': 30.04, 'dissolved_oxygen': 8.26}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385489, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.29, 'ph_level': 7.9, 'turbidity': 30.59, 'dissolved_oxygen': 5.31}
# Received sensor=b'sensor_008': {'sensor_id': 'sensor_008', 'timestamp': 1772385489, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.75, 'ph_level': 8.77, 'turbidity': 7.3, 'dissolved_oxygen': 10.08}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385491, 'prediction': 0, 'prob_class0': 0.9, 'prob_class1': 0.1, 'water_temperature': 28.94, 'ph_level': 8.47, 'turbidity': 36.56, 'dissolved_oxygen': 8.55}
# Received sensor=b'sensor_001': {'sensor_id': 'sensor_001', 'timestamp': 1772385491, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.59, 'ph_level': 8.61, 'turbidity': 6.21, 'dissolved_oxygen': 11.02}
# Received sensor=b'sensor_002': {'sensor_id': 'sensor_002', 'timestamp': 1772385491, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.42, 'ph_level': 8.33, 'turbidity': 12.93, 'dissolved_oxygen': 11.93}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385491, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.99, 'ph_level': 8.01, 'turbidity': 25.6, 'dissolved_oxygen': 6.22}
# Received sensor=b'sensor_004': {'sensor_id': 'sensor_004', 'timestamp': 1772385491, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.33, 'ph_level': 7.97, 'turbidity': 31.54, 'dissolved_oxygen': 11.59}
# Received sensor=b'sensor_005': {'sensor_id': 'sensor_005', 'timestamp': 1772385491, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.11, 'ph_level': 8.08, 'turbidity': 40.83, 'dissolved_oxygen': 10.66}
# Received sensor=b'sensor_006': {'sensor_id': 'sensor_006', 'timestamp': 1772385491, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 30.01, 'ph_level': 8.07, 'turbidity': 38.36, 'dissolved_oxygen': 9.78}
# Received sensor=b'sensor_008': {'sensor_id': 'sensor_008', 'timestamp': 1772385491, 'prediction': 0, 'prob_class0': 0.9, 'prob_class1': 0.1, 'water_temperature': 28.65, 'ph_level': 8.62, 'turbidity': 48.99, 'dissolved_oxygen': 8.7}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385491, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.44, 'ph_level': 8.01, 'turbidity': 8.59, 'dissolved_oxygen': 6.93}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385491, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.05, 'ph_level': 8.31, 'turbidity': 15.23, 'dissolved_oxygen': 7.26}
# Received sensor=b'sensor_001': {'sensor_id': 'sensor_001', 'timestamp': 1772385493, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.31, 'ph_level': 8.6, 'turbidity': 16.35, 'dissolved_oxygen': 9.61}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385493, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.24, 'ph_level': 8.41, 'turbidity': 40.85, 'dissolved_oxygen': 6.55}
# Received sensor=b'sensor_002': {'sensor_id': 'sensor_002', 'timestamp': 1772385493, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.34, 'ph_level': 8.73, 'turbidity': 15.07, 'dissolved_oxygen': 7.08}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385493, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.21, 'ph_level': 8.01, 'turbidity': 10.5, 'dissolved_oxygen': 6.52}
# Received sensor=b'sensor_005': {'sensor_id': 'sensor_005', 'timestamp': 1772385493, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.97, 'ph_level': 8.31, 'turbidity': 23.48, 'dissolved_oxygen': 8.27}
# Received sensor=b'sensor_004': {'sensor_id': 'sensor_004', 'timestamp': 1772385493, 'prediction': 0, 'prob_class0': 0.9, 'prob_class1': 0.1, 'water_temperature': 28.71, 'ph_level': 8.58, 'turbidity': 26.66, 'dissolved_oxygen': 8.79}
# Received sensor=b'sensor_006': {'sensor_id': 'sensor_006', 'timestamp': 1772385493, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.35, 'ph_level': 8.35, 'turbidity': 14.93, 'dissolved_oxygen': 10.47}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385493, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.31, 'ph_level': 8.06, 'turbidity': 18.7, 'dissolved_oxygen': 5.8}
# Received sensor=b'sensor_008': {'sensor_id': 'sensor_008', 'timestamp': 1772385493, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.83, 'ph_level': 7.91, 'turbidity': 15.1, 'dissolved_oxygen': 10.29}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385493, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.6, 'ph_level': 8.31, 'turbidity': 29.2, 'dissolved_oxygen': 11.12}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385495, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.79, 'ph_level': 8.72, 'turbidity': 34.73, 'dissolved_oxygen': 9.16}
# Received sensor=b'sensor_001': {'sensor_id': 'sensor_001', 'timestamp': 1772385495, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.8, 'ph_level': 8.61, 'turbidity': 41.27, 'dissolved_oxygen': 8.62}
# Received sensor=b'sensor_002': {'sensor_id': 'sensor_002', 'timestamp': 1772385495, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.03, 'ph_level': 7.86, 'turbidity': 19.47, 'dissolved_oxygen': 9.3}
# Received sensor=b'sensor_004': {'sensor_id': 'sensor_004', 'timestamp': 1772385495, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.53, 'ph_level': 8.62, 'turbidity': 40.74, 'dissolved_oxygen': 11.51}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385495, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.57, 'ph_level': 7.9, 'turbidity': 15.47, 'dissolved_oxygen': 8.74}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385495, 'prediction': 1, 'prob_class0': 0.1, 'prob_class1': 0.9, 'water_temperature': 29.87, 'ph_level': 8.49, 'turbidity': 10.43, 'dissolved_oxygen': 6.18}
# Received sensor=b'sensor_008': {'sensor_id': 'sensor_008', 'timestamp': 1772385495, 'prediction': 1, 'prob_class0': 0.1, 'prob_class1': 0.9, 'water_temperature': 29.83, 'ph_level': 7.9, 'turbidity': 31.19, 'dissolved_oxygen': 6.25}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385495, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.09, 'ph_level': 8.21, 'turbidity': 32.37, 'dissolved_oxygen': 9.31}
# Received sensor=b'sensor_006': {'sensor_id': 'sensor_006', 'timestamp': 1772385495, 'prediction': 0, 'prob_class0': 0.9, 'prob_class1': 0.1, 'water_temperature': 28.21, 'ph_level': 8.46, 'turbidity': 7.83, 'dissolved_oxygen': 11.0}
# Received sensor=b'sensor_005': {'sensor_id': 'sensor_005', 'timestamp': 1772385495, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 30.0, 'ph_level': 8.26, 'turbidity': 34.78, 'dissolved_oxygen': 5.99}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385497, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.08, 'ph_level': 7.87, 'turbidity': 22.9, 'dissolved_oxygen': 9.55}
# Received sensor=b'sensor_001': {'sensor_id': 'sensor_001', 'timestamp': 1772385497, 'prediction': 0, 'prob_class0': 0.6, 'prob_class1': 0.4, 'water_temperature': 28.93, 'ph_level': 8.69, 'turbidity': 28.45, 'dissolved_oxygen': 8.06}
# Received sensor=b'sensor_002': {'sensor_id': 'sensor_002', 'timestamp': 1772385497, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.83, 'ph_level': 7.89, 'turbidity': 26.13, 'dissolved_oxygen': 9.71}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385497, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.28, 'ph_level': 8.14, 'turbidity': 32.89, 'dissolved_oxygen': 6.32}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385497, 'prediction': 0, 'prob_class0': 0.8, 'prob_class1': 0.2, 'water_temperature': 29.01, 'ph_level': 8.15, 'turbidity': 22.79, 'dissolved_oxygen': 8.4}
# Received sensor=b'sensor_004': {'sensor_id': 'sensor_004', 'timestamp': 1772385497, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.35, 'ph_level': 8.56, 'turbidity': 5.72, 'dissolved_oxygen': 10.77}
# Received sensor=b'sensor_008': {'sensor_id': 'sensor_008', 'timestamp': 1772385497, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.34, 'ph_level': 8.18, 'turbidity': 30.92, 'dissolved_oxygen': 6.96}
# Received sensor=b'sensor_006': {'sensor_id': 'sensor_006', 'timestamp': 1772385497, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.57, 'ph_level': 8.38, 'turbidity': 6.69, 'dissolved_oxygen': 9.96}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385497, 'prediction': 0, 'prob_class0': 0.7, 'prob_class1': 0.3, 'water_temperature': 28.73, 'ph_level': 8.05, 'turbidity': 32.26, 'dissolved_oxygen': 8.36}
# Received sensor=b'sensor_005': {'sensor_id': 'sensor_005', 'timestamp': 1772385497, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.59, 'ph_level': 7.97, 'turbidity': 44.74, 'dissolved_oxygen': 8.97}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385500, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.07, 'ph_level': 8.44, 'turbidity': 37.69, 'dissolved_oxygen': 11.48}
# Received sensor=b'sensor_001': {'sensor_id': 'sensor_001', 'timestamp': 1772385500, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.8, 'ph_level': 8.63, 'turbidity': 36.77, 'dissolved_oxygen': 8.76}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385500, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.29, 'ph_level': 8.44, 'turbidity': 39.22, 'dissolved_oxygen': 5.6}
# Received sensor=b'sensor_006': {'sensor_id': 'sensor_006', 'timestamp': 1772385500, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.46, 'ph_level': 8.49, 'turbidity': 19.77, 'dissolved_oxygen': 9.26}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385500, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.85, 'ph_level': 8.22, 'turbidity': 5.79, 'dissolved_oxygen': 7.77}
# Received sensor=b'sensor_005': {'sensor_id': 'sensor_005', 'timestamp': 1772385500, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.56, 'ph_level': 8.62, 'turbidity': 20.33, 'dissolved_oxygen': 5.36}
# Received sensor=b'sensor_004': {'sensor_id': 'sensor_004', 'timestamp': 1772385500, 'prediction': 0, 'prob_class0': 0.6, 'prob_class1': 0.4, 'water_temperature': 28.93, 'ph_level': 8.45, 'turbidity': 8.26, 'dissolved_oxygen': 8.51}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385500, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.3, 'ph_level': 8.27, 'turbidity': 7.15, 'dissolved_oxygen': 9.96}
# Received sensor=b'sensor_002': {'sensor_id': 'sensor_002', 'timestamp': 1772385500, 'prediction': 0, 'prob_class0': 0.5, 'prob_class1': 0.5, 'water_temperature': 29.23, 'ph_level': 8.83, 'turbidity': 44.32, 'dissolved_oxygen': 7.61}
# Received sensor=b'sensor_008': {'sensor_id': 'sensor_008', 'timestamp': 1772385500, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.94, 'ph_level': 8.43, 'turbidity': 41.22, 'dissolved_oxygen': 11.58}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385502, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.89, 'ph_level': 7.9, 'turbidity': 19.14, 'dissolved_oxygen': 9.54}
# Received sensor=b'sensor_001': {'sensor_id': 'sensor_001', 'timestamp': 1772385502, 'prediction': 0, 'prob_class0': 0.9, 'prob_class1': 0.1, 'water_temperature': 28.44, 'ph_level': 8.81, 'turbidity': 10.18, 'dissolved_oxygen': 10.83}
# Received sensor=b'sensor_002': {'sensor_id': 'sensor_002', 'timestamp': 1772385502, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.33, 'ph_level': 8.33, 'turbidity': 49.84, 'dissolved_oxygen': 11.25}
# Received sensor=b'sensor_005': {'sensor_id': 'sensor_005', 'timestamp': 1772385502, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.53, 'ph_level': 8.67, 'turbidity': 39.31, 'dissolved_oxygen': 6.09}
# Received sensor=b'sensor_004': {'sensor_id': 'sensor_004', 'timestamp': 1772385502, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.9, 'ph_level': 8.62, 'turbidity': 49.65, 'dissolved_oxygen': 6.7}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385502, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.34, 'ph_level': 8.02, 'turbidity': 37.26, 'dissolved_oxygen': 5.26}
# Received sensor=b'sensor_006': {'sensor_id': 'sensor_006', 'timestamp': 1772385502, 'prediction': 0, 'prob_class0': 0.8, 'prob_class1': 0.2, 'water_temperature': 29.05, 'ph_level': 8.74, 'turbidity': 9.71, 'dissolved_oxygen': 11.95}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385502, 'prediction': 0, 'prob_class0': 0.8, 'prob_class1': 0.2, 'water_temperature': 28.38, 'ph_level': 8.54, 'turbidity': 36.16, 'dissolved_oxygen': 8.09}
# Received sensor=b'sensor_008': {'sensor_id': 'sensor_008', 'timestamp': 1772385502, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.24, 'ph_level': 8.33, 'turbidity': 37.69, 'dissolved_oxygen': 5.17}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385502, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.36, 'ph_level': 8.16, 'turbidity': 5.1, 'dissolved_oxygen': 10.02}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385504, 'prediction': 0, 'prob_class0': 0.7, 'prob_class1': 0.3, 'water_temperature': 28.85, 'ph_level': 7.99, 'turbidity': 34.98, 'dissolved_oxygen': 8.75}
# Received sensor=b'sensor_001': {'sensor_id': 'sensor_001', 'timestamp': 1772385504, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.92, 'ph_level': 8.3, 'turbidity': 47.58, 'dissolved_oxygen': 6.89}
# Received sensor=b'sensor_002': {'sensor_id': 'sensor_002', 'timestamp': 1772385504, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.65, 'ph_level': 8.81, 'turbidity': 46.32, 'dissolved_oxygen': 9.82}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385504, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.29, 'ph_level': 8.05, 'turbidity': 16.6, 'dissolved_oxygen': 11.11}
# Received sensor=b'sensor_004': {'sensor_id': 'sensor_004', 'timestamp': 1772385504, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.74, 'ph_level': 7.9, 'turbidity': 10.94, 'dissolved_oxygen': 10.05}
# Received sensor=b'sensor_006': {'sensor_id': 'sensor_006', 'timestamp': 1772385504, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.33, 'ph_level': 7.98, 'turbidity': 19.4, 'dissolved_oxygen': 10.03}
# Received sensor=b'sensor_005': {'sensor_id': 'sensor_005', 'timestamp': 1772385504, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.73, 'ph_level': 7.86, 'turbidity': 17.62, 'dissolved_oxygen': 10.16}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385504, 'prediction': 0, 'prob_class0': 0.9, 'prob_class1': 0.1, 'water_temperature': 28.8, 'ph_level': 8.25, 'turbidity': 27.05, 'dissolved_oxygen': 8.59}
# Received sensor=b'sensor_008': {'sensor_id': 'sensor_008', 'timestamp': 1772385504, 'prediction': 1, 'prob_class0': 0.2, 'prob_class1': 0.8, 'water_temperature': 29.9, 'ph_level': 8.83, 'turbidity': 28.42, 'dissolved_oxygen': 6.86}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385504, 'prediction': 0, 'prob_class0': 0.5, 'prob_class1': 0.5, 'water_temperature': 28.64, 'ph_level': 7.97, 'turbidity': 44.1, 'dissolved_oxygen': 7.94}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385506, 'prediction': 1, 'prob_class0': 0.1, 'prob_class1': 0.9, 'water_temperature': 28.49, 'ph_level': 8.84, 'turbidity': 23.87, 'dissolved_oxygen': 7.47}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385506, 'prediction': 0, 'prob_class0': 0.9, 'prob_class1': 0.1, 'water_temperature': 28.21, 'ph_level': 8.82, 'turbidity': 22.33, 'dissolved_oxygen': 9.28}
# Received sensor=b'sensor_004': {'sensor_id': 'sensor_004', 'timestamp': 1772385506, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.6, 'ph_level': 8.42, 'turbidity': 30.57, 'dissolved_oxygen': 9.27}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385506, 'prediction': 1, 'prob_class0': 0.3, 'prob_class1': 0.7, 'water_temperature': 29.45, 'ph_level': 8.63, 'turbidity': 34.53, 'dissolved_oxygen': 7.7}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385506, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.89, 'ph_level': 8.02, 'turbidity': 12.73, 'dissolved_oxygen': 7.1}
# Received sensor=b'sensor_006': {'sensor_id': 'sensor_006', 'timestamp': 1772385506, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.75, 'ph_level': 8.72, 'turbidity': 34.59, 'dissolved_oxygen': 5.5}
# Received sensor=b'sensor_002': {'sensor_id': 'sensor_002', 'timestamp': 1772385506, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.51, 'ph_level': 8.21, 'turbidity': 32.1, 'dissolved_oxygen': 8.93}
# Received sensor=b'sensor_001': {'sensor_id': 'sensor_001', 'timestamp': 1772385506, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.82, 'ph_level': 8.74, 'turbidity': 31.46, 'dissolved_oxygen': 5.53}
# Received sensor=b'sensor_005': {'sensor_id': 'sensor_005', 'timestamp': 1772385506, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.58, 'ph_level': 8.58, 'turbidity': 32.65, 'dissolved_oxygen': 6.08}
# Received sensor=b'sensor_008': {'sensor_id': 'sensor_008', 'timestamp': 1772385506, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.84, 'ph_level': 8.0, 'turbidity': 11.77, 'dissolved_oxygen': 9.39}
# Received sensor=b'sensor_001': {'sensor_id': 'sensor_001', 'timestamp': 1772385508, 'prediction': 1, 'prob_class0': 0.3, 'prob_class1': 0.7, 'water_temperature': 28.77, 'ph_level': 8.75, 'turbidity': 49.01, 'dissolved_oxygen': 7.62}
# Received sensor=b'sensor_002': {'sensor_id': 'sensor_002', 'timestamp': 1772385508, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.85, 'ph_level': 8.51, 'turbidity': 42.53, 'dissolved_oxygen': 6.44}
# Received sensor=b'sensor_004': {'sensor_id': 'sensor_004', 'timestamp': 1772385508, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.75, 'ph_level': 7.98, 'turbidity': 37.18, 'dissolved_oxygen': 9.97}
# Received sensor=b'sensor_005': {'sensor_id': 'sensor_005', 'timestamp': 1772385508, 'prediction': 0, 'prob_class0': 0.9, 'prob_class1': 0.1, 'water_temperature': 28.52, 'ph_level': 8.74, 'turbidity': 12.99, 'dissolved_oxygen': 10.7}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385508, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.98, 'ph_level': 8.41, 'turbidity': 25.54, 'dissolved_oxygen': 8.54}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385508, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.97, 'ph_level': 8.39, 'turbidity': 43.38, 'dissolved_oxygen': 11.39}
# Received sensor=b'sensor_006': {'sensor_id': 'sensor_006', 'timestamp': 1772385508, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.17, 'ph_level': 8.03, 'turbidity': 44.41, 'dissolved_oxygen': 7.01}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385508, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.29, 'ph_level': 8.25, 'turbidity': 31.63, 'dissolved_oxygen': 9.13}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385508, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.73, 'ph_level': 8.64, 'turbidity': 33.53, 'dissolved_oxygen': 5.57}
# Received sensor=b'sensor_008': {'sensor_id': 'sensor_008', 'timestamp': 1772385508, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.62, 'ph_level': 8.52, 'turbidity': 27.09, 'dissolved_oxygen': 11.11}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385510, 'prediction': 0, 'prob_class0': 0.5, 'prob_class1': 0.5, 'water_temperature': 28.67, 'ph_level': 8.45, 'turbidity': 43.12, 'dissolved_oxygen': 7.99}
# Received sensor=b'sensor_004': {'sensor_id': 'sensor_004', 'timestamp': 1772385510, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.22, 'ph_level': 8.07, 'turbidity': 26.2, 'dissolved_oxygen': 5.65}
# Received sensor=b'sensor_001': {'sensor_id': 'sensor_001', 'timestamp': 1772385510, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.45, 'ph_level': 8.27, 'turbidity': 10.82, 'dissolved_oxygen': 5.6}
# Received sensor=b'sensor_002': {'sensor_id': 'sensor_002', 'timestamp': 1772385510, 'prediction': 1, 'prob_class0': 0.3, 'prob_class1': 0.7, 'water_temperature': 28.18, 'ph_level': 8.52, 'turbidity': 12.38, 'dissolved_oxygen': 7.71}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385510, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.82, 'ph_level': 7.9, 'turbidity': 41.04, 'dissolved_oxygen': 5.17}
# Received sensor=b'sensor_005': {'sensor_id': 'sensor_005', 'timestamp': 1772385510, 'prediction': 1, 'prob_class0': 0.3, 'prob_class1': 0.7, 'water_temperature': 29.91, 'ph_level': 8.53, 'turbidity': 27.63, 'dissolved_oxygen': 6.93}
# Received sensor=b'sensor_008': {'sensor_id': 'sensor_008', 'timestamp': 1772385510, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.13, 'ph_level': 8.4, 'turbidity': 47.87, 'dissolved_oxygen': 5.64}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385510, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.98, 'ph_level': 8.04, 'turbidity': 28.33, 'dissolved_oxygen': 11.81}
# Received sensor=b'sensor_006': {'sensor_id': 'sensor_006', 'timestamp': 1772385510, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.4, 'ph_level': 8.05, 'turbidity': 48.98, 'dissolved_oxygen': 7.55}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385510, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.05, 'ph_level': 8.68, 'turbidity': 27.94, 'dissolved_oxygen': 9.56}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385512, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.88, 'ph_level': 8.48, 'turbidity': 36.93, 'dissolved_oxygen': 11.95}
# Received sensor=b'sensor_001': {'sensor_id': 'sensor_001', 'timestamp': 1772385512, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.39, 'ph_level': 8.02, 'turbidity': 42.35, 'dissolved_oxygen': 11.87}
# Received sensor=b'sensor_002': {'sensor_id': 'sensor_002', 'timestamp': 1772385512, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.27, 'ph_level': 8.18, 'turbidity': 46.54, 'dissolved_oxygen': 7.06}
# Received sensor=b'sensor_005': {'sensor_id': 'sensor_005', 'timestamp': 1772385512, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.57, 'ph_level': 8.43, 'turbidity': 34.03, 'dissolved_oxygen': 5.17}
# Received sensor=b'sensor_004': {'sensor_id': 'sensor_004', 'timestamp': 1772385512, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.2, 'ph_level': 8.56, 'turbidity': 13.23, 'dissolved_oxygen': 5.05}
# Received sensor=b'sensor_006': {'sensor_id': 'sensor_006', 'timestamp': 1772385512, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.05, 'ph_level': 8.27, 'turbidity': 33.06, 'dissolved_oxygen': 9.37}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385512, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.55, 'ph_level': 8.01, 'turbidity': 10.4, 'dissolved_oxygen': 11.05}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385512, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.27, 'ph_level': 8.72, 'turbidity': 13.72, 'dissolved_oxygen': 11.2}
# Received sensor=b'sensor_008': {'sensor_id': 'sensor_008', 'timestamp': 1772385512, 'prediction': 0, 'prob_class0': 0.9, 'prob_class1': 0.1, 'water_temperature': 28.3, 'ph_level': 8.17, 'turbidity': 11.41, 'dissolved_oxygen': 8.49}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385512, 'prediction': 0, 'prob_class0': 0.9, 'prob_class1': 0.1, 'water_temperature': 28.76, 'ph_level': 8.75, 'turbidity': 20.76, 'dissolved_oxygen': 11.98}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385514, 'prediction': 1, 'prob_class0': 0.1, 'prob_class1': 0.9, 'water_temperature': 30.0, 'ph_level': 8.05, 'turbidity': 15.07, 'dissolved_oxygen': 6.92}
# ...
# Received sensor=b'sensor_006': {'sensor_id': 'sensor_006', 'timestamp': 1772385522, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.13, 'ph_level': 8.51, 'turbidity': 24.69, 'dissolved_oxygen': 9.12}
# Received sensor=b'sensor_004': {'sensor_id': 'sensor_004', 'timestamp': 1772385522, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.57, 'ph_level': 8.14, 'turbidity': 46.79, 'dissolved_oxygen': 10.01}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385522, 'prediction': 0, 'prob_class0': 0.5, 'prob_class1': 0.5, 'water_temperature': 28.97, 'ph_level': 8.37, 'turbidity': 27.39, 'dissolved_oxygen': 8.18}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385522, 'prediction': 0, 'prob_class0': 0.5, 'prob_class1': 0.5, 'water_temperature': 28.88, 'ph_level': 8.85, 'turbidity': 7.26, 'dissolved_oxygen': 8.45}
# Received sensor=b'sensor_008': {'sensor_id': 'sensor_008', 'timestamp': 1772385522, 'prediction': 0, 'prob_class0': 0.8, 'prob_class1': 0.2, 'water_temperature': 29.38, 'ph_level': 8.31, 'turbidity': 40.02, 'dissolved_oxygen': 8.62}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385522, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.3, 'ph_level': 8.2, 'turbidity': 44.4, 'dissolved_oxygen': 5.5}
# Received sensor=b'sensor_005': {'sensor_id': 'sensor_005', 'timestamp': 1772385522, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.8, 'ph_level': 8.85, 'turbidity': 38.84, 'dissolved_oxygen': 9.77}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385524, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.08, 'ph_level': 8.38, 'turbidity': 45.0, 'dissolved_oxygen': 11.43}
# Received sensor=b'sensor_002': {'sensor_id': 'sensor_002', 'timestamp': 1772385524, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.42, 'ph_level': 8.53, 'turbidity': 43.88, 'dissolved_oxygen': 5.75}
# Received sensor=b'sensor_001': {'sensor_id': 'sensor_001', 'timestamp': 1772385524, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.1, 'ph_level': 8.67, 'turbidity': 21.62, 'dissolved_oxygen': 9.03}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385524, 'prediction': 0, 'prob_class0': 0.6, 'prob_class1': 0.4, 'water_temperature': 28.11, 'ph_level': 8.06, 'turbidity': 29.14, 'dissolved_oxygen': 8.2}
# Received sensor=b'sensor_004': {'sensor_id': 'sensor_004', 'timestamp': 1772385524, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.06, 'ph_level': 8.77, 'turbidity': 46.62, 'dissolved_oxygen': 5.02}
# Received sensor=b'sensor_005': {'sensor_id': 'sensor_005', 'timestamp': 1772385524, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.43, 'ph_level': 7.9, 'turbidity': 9.79, 'dissolved_oxygen': 8.95}
# Received sensor=b'sensor_006': {'sensor_id': 'sensor_006', 'timestamp': 1772385524, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.49, 'ph_level': 8.53, 'turbidity': 6.38, 'dissolved_oxygen': 9.64}
# Received sensor=b'sensor_008': {'sensor_id': 'sensor_008', 'timestamp': 1772385524, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.61, 'ph_level': 8.82, 'turbidity': 36.18, 'dissolved_oxygen': 5.63}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385524, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.98, 'ph_level': 8.64, 'turbidity': 12.35, 'dissolved_oxygen': 11.37}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385524, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.65, 'ph_level': 8.36, 'turbidity': 24.87, 'dissolved_oxygen': 5.9}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385526, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.49, 'ph_level': 8.47, 'turbidity': 12.79, 'dissolved_oxygen': 9.96}
# Received sensor=b'sensor_002': {'sensor_id': 'sensor_002', 'timestamp': 1772385526, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.59, 'ph_level': 8.51, 'turbidity': 30.29, 'dissolved_oxygen': 8.5}
# Received sensor=b'sensor_001': {'sensor_id': 'sensor_001', 'timestamp': 1772385526, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.16, 'ph_level': 7.99, 'turbidity': 15.42, 'dissolved_oxygen': 10.71}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385526, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 30.0, 'ph_level': 8.72, 'turbidity': 16.12, 'dissolved_oxygen': 10.72}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385526, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.16, 'ph_level': 8.43, 'turbidity': 43.7, 'dissolved_oxygen': 9.31}
# Received sensor=b'sensor_004': {'sensor_id': 'sensor_004', 'timestamp': 1772385526, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 29.15, 'ph_level': 8.46, 'turbidity': 12.93, 'dissolved_oxygen': 5.95}
# Received sensor=b'sensor_006': {'sensor_id': 'sensor_006', 'timestamp': 1772385526, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.42, 'ph_level': 8.08, 'turbidity': 16.49, 'dissolved_oxygen': 10.33}
# Received sensor=b'sensor_008': {'sensor_id': 'sensor_008', 'timestamp': 1772385526, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.28, 'ph_level': 8.25, 'turbidity': 10.71, 'dissolved_oxygen': 5.94}
# Received sensor=b'sensor_005': {'sensor_id': 'sensor_005', 'timestamp': 1772385526, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.88, 'ph_level': 8.32, 'turbidity': 29.55, 'dissolved_oxygen': 8.75}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385526, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.38, 'ph_level': 8.33, 'turbidity': 40.51, 'dissolved_oxygen': 6.75}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385528, 'prediction': 0, 'prob_class0': 0.6, 'prob_class1': 0.4, 'water_temperature': 29.62, 'ph_level': 8.7, 'turbidity': 39.3, 'dissolved_oxygen': 7.26}
# Received sensor=b'sensor_001': {'sensor_id': 'sensor_001', 'timestamp': 1772385528, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.52, 'ph_level': 7.92, 'turbidity': 20.95, 'dissolved_oxygen': 10.07}
# Received sensor=b'sensor_005': {'sensor_id': 'sensor_005', 'timestamp': 1772385528, 'prediction': 1, 'prob_class0': 0.2, 'prob_class1': 0.8, 'water_temperature': 28.15, 'ph_level': 8.39, 'turbidity': 17.18, 'dissolved_oxygen': 7.71}
# Received sensor=b'sensor_002': {'sensor_id': 'sensor_002', 'timestamp': 1772385528, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.46, 'ph_level': 8.23, 'turbidity': 46.75, 'dissolved_oxygen': 11.73}
# Received sensor=b'sensor_007': {'sensor_id': 'sensor_007', 'timestamp': 1772385528, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 30.03, 'ph_level': 8.76, 'turbidity': 44.89, 'dissolved_oxygen': 5.66}
# Received sensor=b'sensor_006': {'sensor_id': 'sensor_006', 'timestamp': 1772385528, 'prediction': 1, 'prob_class0': 0.1, 'prob_class1': 0.9, 'water_temperature': 29.28, 'ph_level': 8.48, 'turbidity': 40.29, 'dissolved_oxygen': 7.77}
# Received sensor=b'sensor_004': {'sensor_id': 'sensor_004', 'timestamp': 1772385528, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 28.74, 'ph_level': 8.15, 'turbidity': 36.71, 'dissolved_oxygen': 9.51}
# Received sensor=b'sensor_003': {'sensor_id': 'sensor_003', 'timestamp': 1772385528, 'prediction': 1, 'prob_class0': 0.0, 'prob_class1': 1.0, 'water_temperature': 28.34, 'ph_level': 8.83, 'turbidity': 6.43, 'dissolved_oxygen': 5.48}
# Received sensor=b'sensor_008': {'sensor_id': 'sensor_008', 'timestamp': 1772385528, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.92, 'ph_level': 8.6, 'turbidity': 14.02, 'dissolved_oxygen': 10.11}
# Received sensor=b'sensor_009': {'sensor_id': 'sensor_009', 'timestamp': 1772385528, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.56, 'ph_level': 8.57, 'turbidity': 22.9, 'dissolved_oxygen': 8.85}
# Received sensor=b'sensor_000': {'sensor_id': 'sensor_000', 'timestamp': 1772385531, 'prediction': 0, 'prob_class0': 1.0, 'prob_class1': 0.0, 'water_temperature': 29.63, 'ph_level': 8.61, 'turbidity': 6.95, 'dissolved_oxygen': 8.69}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /usr/local/lib/python3.10/dist-packages/matplotlib/cbook.py:2043, in _setattr_cm(obj, **kwargs)
#    2042 try:
# -> 2043     for attr, val in kwargs.items():
#    2044         setattr(obj, attr, val)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 107
#     104 plt.ylabel("Confidence")
#     105 plt.ylim(0.0, 1.05)
# --> 107 plt.subplot(2, 2, 4)
#     108 plt.axis("off")
#     110 plt.tight_layout()
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py:1562, in subplot(*args, **kwargs)
#    1559         break
#    1560 else:
#    1561     # we have exhausted the known Axes and none match, make a new one!
# -> 1562     ax = fig.add_subplot(*args, **kwargs)
#    1564 fig.sca(ax)
#    1566 return ax
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/figure.py:768, in FigureBase.add_subplot(self, *args, **kwargs)
#     766         args = tuple(map(int, str(args[0])))
#     767     projection_class, pkw = self._process_projection_requirements(**kwargs)
# --> 768     ax = projection_class(self, *args, **pkw)
#     769     key = (projection_class, pkw)
#     770 return self._add_axes_internal(ax, key)
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py:696, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, forward_navigation_events, *args, **kwargs)
#     693 self.set_axisbelow(mpl.rcParams['axes.axisbelow'])
#     695 self._rasterization_zorder = None
# --> 696 self.clear()
#     698 # funcs used to format x and y - fall back on major formatters
#     699 self.fmt_xdata = None
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py:1416, in _AxesBase.clear(self)
#    1414     self.cla()
#    1415 else:
# -> 1416     self.__clear()
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py:1383, in _AxesBase.__clear(self)
#    1379 self.patch.set_transform(self.transAxes)
#    1381 self.set_axis_on()
# -> 1383 self.xaxis.set_clip_path(self.patch)
#    1384 self.yaxis.set_clip_path(self.patch)
#    1386 if self._sharex is not None:
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py:1128, in Axis.set_clip_path(self, path, transform)
#    1126 def set_clip_path(self, path, transform=None):
#    1127     super().set_clip_path(path, transform)
# -> 1128     for child in self.majorTicks + self.minorTicks:
#    1129         child.set_clip_path(path, transform)
#    1130     self.stale = True
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py:552, in _LazyTickList.__get__(self, instance, owner)
#     550 else:
#     551     instance.minorTicks = []
# --> 552     tick = instance._get_tick(major=False)
#     553     instance.minorTicks = [tick]
#     554     return instance.minorTicks
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py:1603, in Axis._get_tick(self, major)
#    1599     raise NotImplementedError(
#    1600         f"The Axis subclass {self.__class__.__name__} must define "
#    1601         "_tick_class or reimplement _get_tick()")
#    1602 tick_kw = self._major_tick_kw if major else self._minor_tick_kw
# -> 1603 return self._tick_class(self.axes, 0, major=major, **tick_kw)
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py:368, in XTick.__init__(self, *args, **kwargs)
#     367 def __init__(self, *args, **kwargs):
# --> 368     super().__init__(*args, **kwargs)
#     369     # x in data coords, y in axes coords
#     370     ax = self.axes
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py:172, in Tick.__init__(self, axes, loc, size, width, color, tickdir, pad, labelsize, labelcolor, labelfontfamily, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kwargs)
#     164 self.gridline = mlines.Line2D(
#     165     [], [],
#     166     color=grid_color, alpha=grid_alpha, visible=gridOn,
#     167     linestyle=grid_linestyle, linewidth=grid_linewidth, marker="",
#     168     **grid_kw,
#     169 )
#     170 self.gridline.get_path()._interpolation_steps = \
#     171     GRIDLINE_INTERPOLATION_STEPS
# --> 172 self.label1 = mtext.Text(
#     173     np.nan, np.nan,
#     174     fontsize=labelsize, color=labelcolor, visible=label1On,
#     175     fontfamily=labelfontfamily, rotation=self._labelrotation[1])
#     176 self.label2 = mtext.Text(
#     177     np.nan, np.nan,
#     178     fontsize=labelsize, color=labelcolor, visible=label2On,
#     179     fontfamily=labelfontfamily, rotation=self._labelrotation[1])
#     181 self._apply_tickdir(tickdir)
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/text.py:155, in Text.__init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, transform_rotates_text, parse_math, antialiased, **kwargs)
#     138 self._text = ''
#     139 self._reset_visual_defaults(
#     140     text=text,
#     141     color=color,
#    (...)
#     153     antialiased=antialiased
#     154 )
# --> 155 self.update(kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/text.py:205, in Text.update(self, kwargs)
#     203 # Update bbox last, as it depends on font properties.
#     204 bbox = kwargs.pop("bbox", sentinel)
# --> 205 ret.extend(super().update(kwargs))
#     206 if bbox is not sentinel:
#     207     ret.append(self.set_bbox(bbox))
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py:1223, in Artist.update(self, props)
#    1215 def update(self, props):
#    1216     """
#    1217     Update this artist's properties from the dict *props*.
#    1218
#    (...)
#    1221     props : dict
#    1222     """
# -> 1223     return self._update_props(
#    1224         props, "{cls.__name__!r} object has no property {prop_name!r}")
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py:1197, in Artist._update_props(self, props, errfmt)
#    1189 """
#    1190 Helper for `.Artist.set` and `.Artist.update`.
#    1191
#    (...)
#    1194 property name for "{prop_name}".
#    1195 """
#    1196 ret = []
# -> 1197 with cbook._setattr_cm(self, eventson=False):
#    1198     for k, v in props.items():
#    1199         # Allow attributes we want to be able to update through
#    1200         # art.update, art.set, setp.
#    1201         if k == "axes":
#
# File /usr/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/cbook.py:2049, in _setattr_cm(obj, **kwargs)
#    2047 for attr, orig in origs.items():
#    2048     if orig is sentinel:
# -> 2049         delattr(obj, attr)
#    2050     else:
#    2051         setattr(obj, attr, orig)
#
# AttributeError: eventson

# %%
from kafka import KafkaConsumer, KafkaProducer
import json
import matplotlib.pyplot as plt
import time
import joblib
import numpy as np

# %%
# Initialize data storage for plotting
historial = {}
MODEL_PATH = "./aeration_classifier.joblib"
rf_model = joblib.load(MODEL_PATH)
PROCESADOR = "ML B"
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.4.0 when using version 1.6.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator RandomForestClassifier from version 1.4.0 when using version 1.6.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
# Kafka configuration
def initialize_consumer():
    # Kafka configuration
    kafka_topic = "water_quality"
    kafka_bootstrap_servers = ["localhost:9092"]
    # Create Kafka consumer
    consumer = KafkaConsumer(
        kafka_topic,
        bootstrap_servers=kafka_bootstrap_servers,
        value_deserializer=lambda m: json.loads(m.decode('utf-8')),
        auto_offset_reset='latest',
        enable_auto_commit=True
        )
    return consumer

def initialize_result_producer():
    kafka_bootstrap_servers = ["localhost:9092"]
    producer = KafkaProducer(bootstrap_servers=kafka_bootstrap_servers, value_serializer=lambda v: json.dumps(v).encode('utf-8'))
    return producer

# %%
# Receive all published messages and update plot
def update_plot(consumer, producer):
    try:
        for message in consumer:
            # Parse the message
            sensor_data = message.value
            sensor_id = message.key.decode("utf-8") if message.key else "no_key"
            print(f"Received: sensor_id:{sensor_id},{sensor_data}")

            predicciones = [[sensor_data['water_temperature'], sensor_data['ph_level'], sensor_data['turbidity'], sensor_data['dissolved_oxygen']]]
            
            proba = rf_model.predict_proba(predicciones)[0]   # [p(clase0), p(clase1)]
            pred = int(rf_model.predict(predicciones)[0])     # 0/1
            
            resultado = {
                "sensor_id": sensor_id,
                "timestamp": sensor_data['timestamp'],
                "p_class_0": float(proba[0]),
                "p_class_1": float(proba[1]),
                "pred": pred
            }
            if sensor_id not in list(historial.keys()):
                historial[sensor_id] = [[],[], [], []]
            historial[sensor_id][0].append(resultado['timestamp'])
            historial[sensor_id][1].append(resultado['p_class_0'])
            historial[sensor_id][2].append(resultado['p_class_1'])
            historial[sensor_id][3].append(resultado['pred'])
            if len(historial) > 100:
                historial[sensor_id][0].pop(0)
                historial[sensor_id][1].pop(0)
                historial[sensor_id][2].pop(0)
                historial[sensor_id][3].pop(0)
            
            topico = "water_end"
            producer.send(topico, key=message.key, value=resultado)
            print(f"Datos del proceso de aireación {PROCESADOR} del sensor {sensor_id}: {resultado}")
            # Clear the current axes and redraw the plots
            plt.figure(figsize=(10, 8))

            plt.subplot(2, 2, 1)
            plt.plot(historial[sensor_id][0], historial[sensor_id][3], label="Estado arieación por timestamp", color="blue")
            plt.title("Estado arieación por timestamp")
            plt.ylabel("Arieación")

            plt.subplot(2, 2, 2)
            plt.plot(historial[sensor_id][0], historial[sensor_id][1], label="Confianza clase 0/arieación", color="green")
            plt.title("Confianza clase 0/arieación")
            plt.ylabel("Probabilidad clase 0")

            plt.subplot(2, 2, 3)
            plt.plot(historial[sensor_id][0], historial[sensor_id][2], label="Confianza clase 1/no arieación", color="yellow")
            plt.title("Confianza clase 1/arieación")
            plt.ylabel("Probabilidad clase 1")

            plt.tight_layout()

            # Save the plot as an image
            plt.savefig(f"water_quality_plot{sensor_id}.png")
            plt.close()

            break  # Process one message at a time
    except KeyboardInterrupt:
        print("Stopped consuming messages.")
        consumer.close()

# %%
consumer = initialize_consumer()
producer = initialize_result_producer()
print("Subscribed to Kafka topic 'water_quality'.")

try:
    while True:
        update_plot(consumer, producer)
except KeyboardInterrupt:
    print("Stopped visualization.")
    consumer.close()
# Out:
# Subscribed to Kafka topic 'water_quality'.
# Received: sensor_id:0,{'timestamp': 1772387570, 'water_temperature': 28.4620222259529, 'ph_level': 8.470267714857874, 'turbidity': 49.28, 'dissolved_oxygen': 7.63}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387570, 'p_class_0': 0.2, 'p_class_1': 0.8, 'pred': 1}
# Received: sensor_id:2,{'timestamp': 1772387570, 'water_temperature': 29.28788779416022, 'ph_level': 8.10778461092128, 'turbidity': 48.6, 'dissolved_oxygen': 5.42}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387570, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:6,{'timestamp': 1772387570, 'water_temperature': 29.550104589299824, 'ph_level': 8.585891626509017, 'turbidity': 36.2, 'dissolved_oxygen': 7.53}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387570, 'p_class_0': 0.7, 'p_class_1': 0.3, 'pred': 0}
# Received: sensor_id:5,{'timestamp': 1772387570, 'water_temperature': 29.998125750347292, 'ph_level': 7.784929297680902, 'turbidity': 11.53, 'dissolved_oxygen': 7.06}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387570, 'p_class_0': 0.1, 'p_class_1': 0.9, 'pred': 1}
# Received: sensor_id:1,{'timestamp': 1772387570, 'water_temperature': 29.377275349237664, 'ph_level': 8.23932988911184, 'turbidity': 8.15, 'dissolved_oxygen': 10.19}
# Datos del proceso de aireación ML B del sensor 1: {'sensor_id': '1', 'timestamp': 1772387570, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:3,{'timestamp': 1772387570, 'water_temperature': 28.709796781549812, 'ph_level': 7.917089165243505, 'turbidity': 20.13, 'dissolved_oxygen': 6.16}
# Datos del proceso de aireación ML B del sensor 3: {'sensor_id': '3', 'timestamp': 1772387570, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:4,{'timestamp': 1772387570, 'water_temperature': 29.48201088190075, 'ph_level': 8.104505795636673, 'turbidity': 14.83, 'dissolved_oxygen': 6.38}
# Datos del proceso de aireación ML B del sensor 4: {'sensor_id': '4', 'timestamp': 1772387570, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:0,{'timestamp': 1772387571, 'water_temperature': 29.0333444405339, 'ph_level': 8.551834910446305, 'turbidity': 39.56, 'dissolved_oxygen': 7.93}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387571, 'p_class_0': 0.5, 'p_class_1': 0.5, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387571, 'water_temperature': 29.83750247870667, 'ph_level': 7.798067605857332, 'turbidity': 32.94, 'dissolved_oxygen': 9.83}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387571, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387571, 'water_temperature': 30.27170433124031, 'ph_level': 8.401606225162693, 'turbidity': 16.3, 'dissolved_oxygen': 10.35}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387571, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:5,{'timestamp': 1772387571, 'water_temperature': 29.268751464677454, 'ph_level': 7.885012401518397, 'turbidity': 10.68, 'dissolved_oxygen': 10.59}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387571, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387572, 'water_temperature': 29.477487489908693, 'ph_level': 8.093208005139516, 'turbidity': 5.89, 'dissolved_oxygen': 8.22}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387572, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387572, 'water_temperature': 28.749837870639773, 'ph_level': 7.854764036009842, 'turbidity': 5.24, 'dissolved_oxygen': 6.2}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387572, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:6,{'timestamp': 1772387572, 'water_temperature': 29.155966396011202, 'ph_level': 7.91175435668367, 'turbidity': 47.9, 'dissolved_oxygen': 11.68}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387572, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:5,{'timestamp': 1772387572, 'water_temperature': 29.362887780388157, 'ph_level': 7.993802546797954, 'turbidity': 25.69, 'dissolved_oxygen': 9.99}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387572, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387573, 'water_temperature': 29.279102768107844, 'ph_level': 8.124320491172522, 'turbidity': 21.4, 'dissolved_oxygen': 8.93}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387573, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387573, 'water_temperature': 29.743169495910013, 'ph_level': 8.24874348122123, 'turbidity': 32.74, 'dissolved_oxygen': 5.4}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387573, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:5,{'timestamp': 1772387573, 'water_temperature': 28.893712725481162, 'ph_level': 8.251752786105381, 'turbidity': 38.52, 'dissolved_oxygen': 9.53}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387573, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387573, 'water_temperature': 30.294596481234763, 'ph_level': 7.9864628672452005, 'turbidity': 42.28, 'dissolved_oxygen': 5.08}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387573, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:1,{'timestamp': 1772387571, 'water_temperature': 29.84809942851206, 'ph_level': 8.440450588409632, 'turbidity': 13.26, 'dissolved_oxygen': 7.07}
# Datos del proceso de aireación ML B del sensor 1: {'sensor_id': '1', 'timestamp': 1772387571, 'p_class_0': 0.4, 'p_class_1': 0.6, 'pred': 1}
# Received: sensor_id:3,{'timestamp': 1772387571, 'water_temperature': 28.428731012617433, 'ph_level': 8.634229007912191, 'turbidity': 6.42, 'dissolved_oxygen': 11.25}
# Datos del proceso de aireación ML B del sensor 3: {'sensor_id': '3', 'timestamp': 1772387571, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:4,{'timestamp': 1772387571, 'water_temperature': 30.247813012163657, 'ph_level': 8.04232241477387, 'turbidity': 27.63, 'dissolved_oxygen': 6.19}
# Datos del proceso de aireación ML B del sensor 4: {'sensor_id': '4', 'timestamp': 1772387571, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:1,{'timestamp': 1772387572, 'water_temperature': 30.216015380085565, 'ph_level': 8.182899638040364, 'turbidity': 30.29, 'dissolved_oxygen': 8.31}
# Datos del proceso de aireación ML B del sensor 1: {'sensor_id': '1', 'timestamp': 1772387572, 'p_class_0': 0.9, 'p_class_1': 0.1, 'pred': 0}
# Received: sensor_id:3,{'timestamp': 1772387572, 'water_temperature': 28.435550093054307, 'ph_level': 7.7513542052146525, 'turbidity': 16.77, 'dissolved_oxygen': 8.23}
# Datos del proceso de aireación ML B del sensor 3: {'sensor_id': '3', 'timestamp': 1772387572, 'p_class_0': 0.6, 'p_class_1': 0.4, 'pred': 0}
# Received: sensor_id:4,{'timestamp': 1772387572, 'water_temperature': 30.130060929043427, 'ph_level': 8.474478176264283, 'turbidity': 47.94, 'dissolved_oxygen': 11.94}
# Datos del proceso de aireación ML B del sensor 4: {'sensor_id': '4', 'timestamp': 1772387572, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:1,{'timestamp': 1772387573, 'water_temperature': 29.55168480183724, 'ph_level': 7.960982178573373, 'turbidity': 11.95, 'dissolved_oxygen': 9.09}
# Datos del proceso de aireación ML B del sensor 1: {'sensor_id': '1', 'timestamp': 1772387573, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:3,{'timestamp': 1772387573, 'water_temperature': 29.02795392281272, 'ph_level': 7.99159116031115, 'turbidity': 21.98, 'dissolved_oxygen': 7.25}
# Datos del proceso de aireación ML B del sensor 3: {'sensor_id': '3', 'timestamp': 1772387573, 'p_class_0': 0.1, 'p_class_1': 0.9, 'pred': 1}
# Received: sensor_id:4,{'timestamp': 1772387573, 'water_temperature': 30.32714202714307, 'ph_level': 7.977549008478497, 'turbidity': 33.92, 'dissolved_oxygen': 8.76}
# Datos del proceso de aireación ML B del sensor 4: {'sensor_id': '4', 'timestamp': 1772387573, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387574, 'water_temperature': 29.580494468267638, 'ph_level': 7.730212700268705, 'turbidity': 44.52, 'dissolved_oxygen': 5.6}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387574, 'p_class_0': 0.1, 'p_class_1': 0.9, 'pred': 1}
# Received: sensor_id:2,{'timestamp': 1772387574, 'water_temperature': 29.887089365808926, 'ph_level': 7.802376510115235, 'turbidity': 8.98, 'dissolved_oxygen': 5.63}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387574, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:5,{'timestamp': 1772387574, 'water_temperature': 29.227582828154784, 'ph_level': 8.279637137330504, 'turbidity': 8.48, 'dissolved_oxygen': 10.55}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387574, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387574, 'water_temperature': 30.419661572490238, 'ph_level': 8.08136156224491, 'turbidity': 44.82, 'dissolved_oxygen': 8.96}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387574, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387575, 'water_temperature': 28.548403466742286, 'ph_level': 8.375447227146807, 'turbidity': 21.21, 'dissolved_oxygen': 8.45}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387575, 'p_class_0': 0.8, 'p_class_1': 0.2, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387575, 'water_temperature': 29.267305245095002, 'ph_level': 7.959122123304799, 'turbidity': 10.82, 'dissolved_oxygen': 11.58}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387575, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:5,{'timestamp': 1772387575, 'water_temperature': 29.510982971741793, 'ph_level': 8.603247606481975, 'turbidity': 25.16, 'dissolved_oxygen': 10.73}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387575, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387575, 'water_temperature': 30.072225931139478, 'ph_level': 8.379188228109019, 'turbidity': 8.17, 'dissolved_oxygen': 8.51}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387575, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387576, 'water_temperature': 28.847963398277003, 'ph_level': 8.538525011361529, 'turbidity': 49.5, 'dissolved_oxygen': 8.57}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387576, 'p_class_0': 0.8, 'p_class_1': 0.2, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387576, 'water_temperature': 28.882568012802267, 'ph_level': 7.754608727760261, 'turbidity': 49.19, 'dissolved_oxygen': 6.42}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387576, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:5,{'timestamp': 1772387576, 'water_temperature': 29.387629437296543, 'ph_level': 8.327705776747065, 'turbidity': 23.21, 'dissolved_oxygen': 11.56}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387576, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387576, 'water_temperature': 29.17613532366884, 'ph_level': 7.766435754287193, 'turbidity': 23.84, 'dissolved_oxygen': 10.14}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387576, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387577, 'water_temperature': 29.93201389288119, 'ph_level': 7.822068833532278, 'turbidity': 6.16, 'dissolved_oxygen': 6.22}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387577, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:2,{'timestamp': 1772387577, 'water_temperature': 28.721621511370127, 'ph_level': 7.867231025456221, 'turbidity': 46.24, 'dissolved_oxygen': 7.21}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387577, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:5,{'timestamp': 1772387577, 'water_temperature': 29.02159414462593, 'ph_level': 7.843083519804068, 'turbidity': 33.14, 'dissolved_oxygen': 9.23}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387577, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387577, 'water_temperature': 29.39026789557945, 'ph_level': 7.697451366605956, 'turbidity': 8.79, 'dissolved_oxygen': 5.09}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387577, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:0,{'timestamp': 1772387578, 'water_temperature': 30.289183972444818, 'ph_level': 8.010034555643971, 'turbidity': 22.78, 'dissolved_oxygen': 10.05}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387578, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387578, 'water_temperature': 28.63033832245406, 'ph_level': 8.517582251148456, 'turbidity': 7.41, 'dissolved_oxygen': 9.37}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387578, 'p_class_0': 0.9, 'p_class_1': 0.1, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387578, 'water_temperature': 29.75376408682544, 'ph_level': 8.244470368786411, 'turbidity': 40.17, 'dissolved_oxygen': 5.28}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387578, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:5,{'timestamp': 1772387578, 'water_temperature': 29.19131295248293, 'ph_level': 7.762493873379841, 'turbidity': 27.81, 'dissolved_oxygen': 11.74}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387578, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387579, 'water_temperature': 28.608858850871233, 'ph_level': 8.60470397708389, 'turbidity': 23.94, 'dissolved_oxygen': 8.44}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387579, 'p_class_0': 0.9, 'p_class_1': 0.1, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387579, 'water_temperature': 29.259627439024225, 'ph_level': 8.468437646195989, 'turbidity': 49.74, 'dissolved_oxygen': 5.58}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387579, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:5,{'timestamp': 1772387579, 'water_temperature': 29.255358959422917, 'ph_level': 8.023242702745433, 'turbidity': 29.59, 'dissolved_oxygen': 5.81}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387579, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:6,{'timestamp': 1772387579, 'water_temperature': 29.74625981923121, 'ph_level': 8.55490308052797, 'turbidity': 27.57, 'dissolved_oxygen': 10.54}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387579, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387580, 'water_temperature': 28.515129511458383, 'ph_level': 8.348640982795317, 'turbidity': 42.99, 'dissolved_oxygen': 8.33}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387580, 'p_class_0': 0.6, 'p_class_1': 0.4, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387580, 'water_temperature': 29.18494251625309, 'ph_level': 8.526316932423573, 'turbidity': 38.21, 'dissolved_oxygen': 8.72}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387580, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387580, 'water_temperature': 29.085406405535135, 'ph_level': 7.778839376725833, 'turbidity': 23.43, 'dissolved_oxygen': 5.84}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387580, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:5,{'timestamp': 1772387580, 'water_temperature': 29.015367209435162, 'ph_level': 8.66098980905723, 'turbidity': 5.25, 'dissolved_oxygen': 9.46}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387580, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387581, 'water_temperature': 30.234373756618922, 'ph_level': 8.151782491381992, 'turbidity': 15.99, 'dissolved_oxygen': 5.88}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387581, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:2,{'timestamp': 1772387581, 'water_temperature': 29.814465779202994, 'ph_level': 8.24676159465947, 'turbidity': 47.95, 'dissolved_oxygen': 5.59}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387581, 'p_class_0': 0.1, 'p_class_1': 0.9, 'pred': 1}
# Received: sensor_id:6,{'timestamp': 1772387581, 'water_temperature': 29.702224741087257, 'ph_level': 8.334316968673644, 'turbidity': 27.89, 'dissolved_oxygen': 8.03}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387581, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:5,{'timestamp': 1772387581, 'water_temperature': 28.860020559615418, 'ph_level': 8.403508523109531, 'turbidity': 27.44, 'dissolved_oxygen': 8.32}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387581, 'p_class_0': 0.7, 'p_class_1': 0.3, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387582, 'water_temperature': 28.524376128232188, 'ph_level': 8.119721767148354, 'turbidity': 47.96, 'dissolved_oxygen': 9.36}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387582, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:5,{'timestamp': 1772387582, 'water_temperature': 29.22620079830948, 'ph_level': 8.327340871407035, 'turbidity': 14.09, 'dissolved_oxygen': 10.2}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387582, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387582, 'water_temperature': 28.579331259256715, 'ph_level': 8.491469696053217, 'turbidity': 41.32, 'dissolved_oxygen': 10.68}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387582, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387582, 'water_temperature': 29.75162203832444, 'ph_level': 7.850470871786437, 'turbidity': 11.63, 'dissolved_oxygen': 7.78}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387582, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387583, 'water_temperature': 29.979272634683856, 'ph_level': 8.158442004456994, 'turbidity': 38.01, 'dissolved_oxygen': 6.02}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387583, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:6,{'timestamp': 1772387583, 'water_temperature': 28.75922803618308, 'ph_level': 8.208126654642852, 'turbidity': 43.66, 'dissolved_oxygen': 5.85}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387583, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:5,{'timestamp': 1772387583, 'water_temperature': 28.600822506065136, 'ph_level': 8.231586056860577, 'turbidity': 13.2, 'dissolved_oxygen': 8.29}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387583, 'p_class_0': 0.9, 'p_class_1': 0.1, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387583, 'water_temperature': 29.411703766072577, 'ph_level': 8.132509993304174, 'turbidity': 23.82, 'dissolved_oxygen': 10.77}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387583, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387584, 'water_temperature': 30.252744178058833, 'ph_level': 8.286035527354768, 'turbidity': 43.49, 'dissolved_oxygen': 10.87}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387584, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387584, 'water_temperature': 29.338036637628655, 'ph_level': 8.47121816946666, 'turbidity': 5.49, 'dissolved_oxygen': 6.7}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387584, 'p_class_0': 0.1, 'p_class_1': 0.9, 'pred': 1}
# Received: sensor_id:5,{'timestamp': 1772387584, 'water_temperature': 28.741362240316302, 'ph_level': 7.967021013869767, 'turbidity': 25.22, 'dissolved_oxygen': 8.6}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387584, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387584, 'water_temperature': 29.48627894581004, 'ph_level': 8.582339051332662, 'turbidity': 23.15, 'dissolved_oxygen': 6.81}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387584, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:3,{'timestamp': 1772387574, 'water_temperature': 28.764944715789053, 'ph_level': 7.83726008288046, 'turbidity': 5.99, 'dissolved_oxygen': 10.06}
# Datos del proceso de aireación ML B del sensor 3: {'sensor_id': '3', 'timestamp': 1772387574, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:1,{'timestamp': 1772387574, 'water_temperature': 29.10883579314852, 'ph_level': 8.518507117579494, 'turbidity': 17.36, 'dissolved_oxygen': 5.65}
# Datos del proceso de aireación ML B del sensor 1: {'sensor_id': '1', 'timestamp': 1772387574, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:4,{'timestamp': 1772387574, 'water_temperature': 28.617539095790185, 'ph_level': 8.535690296372927, 'turbidity': 27.23, 'dissolved_oxygen': 9.21}
# Datos del proceso de aireación ML B del sensor 4: {'sensor_id': '4', 'timestamp': 1772387574, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:1,{'timestamp': 1772387575, 'water_temperature': 28.923576869683373, 'ph_level': 8.278869861318306, 'turbidity': 17.56, 'dissolved_oxygen': 11.37}
# Datos del proceso de aireación ML B del sensor 1: {'sensor_id': '1', 'timestamp': 1772387575, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:3,{'timestamp': 1772387575, 'water_temperature': 29.396614138040146, 'ph_level': 8.328169390963021, 'turbidity': 18.12, 'dissolved_oxygen': 9.99}
# Datos del proceso de aireación ML B del sensor 3: {'sensor_id': '3', 'timestamp': 1772387575, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:4,{'timestamp': 1772387575, 'water_temperature': 28.87607474617487, 'ph_level': 7.9813368375850775, 'turbidity': 32.9, 'dissolved_oxygen': 5.02}
# Datos del proceso de aireación ML B del sensor 4: {'sensor_id': '4', 'timestamp': 1772387575, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:1,{'timestamp': 1772387576, 'water_temperature': 29.348075551983094, 'ph_level': 8.092442447993484, 'turbidity': 14.5, 'dissolved_oxygen': 7.11}
# Datos del proceso de aireación ML B del sensor 1: {'sensor_id': '1', 'timestamp': 1772387576, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:3,{'timestamp': 1772387576, 'water_temperature': 29.07955830299535, 'ph_level': 7.833914834466375, 'turbidity': 43.79, 'dissolved_oxygen': 8.58}
# Datos del proceso de aireación ML B del sensor 3: {'sensor_id': '3', 'timestamp': 1772387576, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:4,{'timestamp': 1772387576, 'water_temperature': 29.370483200976704, 'ph_level': 8.504495619810948, 'turbidity': 33.52, 'dissolved_oxygen': 5.26}
# Datos del proceso de aireación ML B del sensor 4: {'sensor_id': '4', 'timestamp': 1772387576, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:1,{'timestamp': 1772387577, 'water_temperature': 29.07088796005622, 'ph_level': 8.15345679966178, 'turbidity': 40.48, 'dissolved_oxygen': 11.03}
# Datos del proceso de aireación ML B del sensor 1: {'sensor_id': '1', 'timestamp': 1772387577, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:3,{'timestamp': 1772387577, 'water_temperature': 29.060089200041244, 'ph_level': 8.601858299814332, 'turbidity': 14.71, 'dissolved_oxygen': 11.84}
# Datos del proceso de aireación ML B del sensor 3: {'sensor_id': '3', 'timestamp': 1772387577, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:4,{'timestamp': 1772387577, 'water_temperature': 29.506114697409217, 'ph_level': 8.40766776433605, 'turbidity': 22.5, 'dissolved_oxygen': 10.74}
# Datos del proceso de aireación ML B del sensor 4: {'sensor_id': '4', 'timestamp': 1772387577, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:1,{'timestamp': 1772387578, 'water_temperature': 29.745773725292246, 'ph_level': 8.543211887107235, 'turbidity': 49.99, 'dissolved_oxygen': 7.88}
# Datos del proceso de aireación ML B del sensor 1: {'sensor_id': '1', 'timestamp': 1772387578, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:4,{'timestamp': 1772387578, 'water_temperature': 29.947504324260223, 'ph_level': 8.223376750396923, 'turbidity': 48.17, 'dissolved_oxygen': 6.58}
# Datos del proceso de aireación ML B del sensor 4: {'sensor_id': '4', 'timestamp': 1772387578, 'p_class_0': 0.1, 'p_class_1': 0.9, 'pred': 1}
# Received: sensor_id:3,{'timestamp': 1772387578, 'water_temperature': 29.512898138869367, 'ph_level': 7.800275399666022, 'turbidity': 25.91, 'dissolved_oxygen': 8.71}
# Datos del proceso de aireación ML B del sensor 3: {'sensor_id': '3', 'timestamp': 1772387578, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:3,{'timestamp': 1772387579, 'water_temperature': 29.728221051267653, 'ph_level': 8.6278020118762, 'turbidity': 17.95, 'dissolved_oxygen': 10.55}
# Datos del proceso de aireación ML B del sensor 3: {'sensor_id': '3', 'timestamp': 1772387579, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:4,{'timestamp': 1772387579, 'water_temperature': 29.628098852349254, 'ph_level': 7.998716822254765, 'turbidity': 21.04, 'dissolved_oxygen': 6.51}
# Datos del proceso de aireación ML B del sensor 4: {'sensor_id': '4', 'timestamp': 1772387579, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:1,{'timestamp': 1772387579, 'water_temperature': 29.485909621521454, 'ph_level': 8.317419879792718, 'turbidity': 40.88, 'dissolved_oxygen': 11.3}
# Datos del proceso de aireación ML B del sensor 1: {'sensor_id': '1', 'timestamp': 1772387579, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:1,{'timestamp': 1772387580, 'water_temperature': 29.305424662427324, 'ph_level': 8.513812642670668, 'turbidity': 19.56, 'dissolved_oxygen': 6.26}
# Datos del proceso de aireación ML B del sensor 1: {'sensor_id': '1', 'timestamp': 1772387580, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:3,{'timestamp': 1772387580, 'water_temperature': 29.514301127502193, 'ph_level': 8.304413848827595, 'turbidity': 19.52, 'dissolved_oxygen': 11.48}
# Datos del proceso de aireación ML B del sensor 3: {'sensor_id': '3', 'timestamp': 1772387580, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:4,{'timestamp': 1772387580, 'water_temperature': 29.199100725116022, 'ph_level': 8.014959845919801, 'turbidity': 35.28, 'dissolved_oxygen': 11.05}
# Datos del proceso de aireación ML B del sensor 4: {'sensor_id': '4', 'timestamp': 1772387580, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:1,{'timestamp': 1772387581, 'water_temperature': 29.9543317795404, 'ph_level': 7.963451883200623, 'turbidity': 45.52, 'dissolved_oxygen': 11.31}
# Datos del proceso de aireación ML B del sensor 1: {'sensor_id': '1', 'timestamp': 1772387581, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:3,{'timestamp': 1772387581, 'water_temperature': 28.811954985720583, 'ph_level': 8.0187587374177, 'turbidity': 12.33, 'dissolved_oxygen': 11.02}
# Datos del proceso de aireación ML B del sensor 3: {'sensor_id': '3', 'timestamp': 1772387581, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:4,{'timestamp': 1772387581, 'water_temperature': 28.713926284279953, 'ph_level': 7.70865582650028, 'turbidity': 20.25, 'dissolved_oxygen': 9.83}
# Datos del proceso de aireación ML B del sensor 4: {'sensor_id': '4', 'timestamp': 1772387581, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:4,{'timestamp': 1772387582, 'water_temperature': 29.60433630671192, 'ph_level': 7.7146511738456285, 'turbidity': 29.14, 'dissolved_oxygen': 5.97}
# Datos del proceso de aireación ML B del sensor 4: {'sensor_id': '4', 'timestamp': 1772387582, 'p_class_0': 0.1, 'p_class_1': 0.9, 'pred': 1}
# Received: sensor_id:3,{'timestamp': 1772387582, 'water_temperature': 29.22037973684798, 'ph_level': 8.208100247092892, 'turbidity': 38.08, 'dissolved_oxygen': 6.52}
# Datos del proceso de aireación ML B del sensor 3: {'sensor_id': '3', 'timestamp': 1772387582, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:1,{'timestamp': 1772387582, 'water_temperature': 29.82813498969001, 'ph_level': 7.821438345535271, 'turbidity': 10.84, 'dissolved_oxygen': 10.62}
# Datos del proceso de aireación ML B del sensor 1: {'sensor_id': '1', 'timestamp': 1772387582, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:1,{'timestamp': 1772387583, 'water_temperature': 28.55650940316362, 'ph_level': 8.364946798850957, 'turbidity': 17.49, 'dissolved_oxygen': 9.23}
# Datos del proceso de aireación ML B del sensor 1: {'sensor_id': '1', 'timestamp': 1772387583, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:3,{'timestamp': 1772387583, 'water_temperature': 29.892285453749587, 'ph_level': 8.125096753111988, 'turbidity': 45.72, 'dissolved_oxygen': 8.18}
# Datos del proceso de aireación ML B del sensor 3: {'sensor_id': '3', 'timestamp': 1772387583, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:4,{'timestamp': 1772387583, 'water_temperature': 28.848890868443597, 'ph_level': 8.633504495156652, 'turbidity': 11.99, 'dissolved_oxygen': 5.28}
# Datos del proceso de aireación ML B del sensor 4: {'sensor_id': '4', 'timestamp': 1772387583, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:1,{'timestamp': 1772387584, 'water_temperature': 29.84104925853, 'ph_level': 8.585415910478366, 'turbidity': 10.66, 'dissolved_oxygen': 11.97}
# Datos del proceso de aireación ML B del sensor 1: {'sensor_id': '1', 'timestamp': 1772387584, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:4,{'timestamp': 1772387584, 'water_temperature': 29.5654689112956, 'ph_level': 7.795913055810142, 'turbidity': 46.6, 'dissolved_oxygen': 10.95}
# Datos del proceso de aireación ML B del sensor 4: {'sensor_id': '4', 'timestamp': 1772387584, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:3,{'timestamp': 1772387584, 'water_temperature': 29.033291410163194, 'ph_level': 8.41708748260664, 'turbidity': 34.09, 'dissolved_oxygen': 11.96}
# Datos del proceso de aireación ML B del sensor 3: {'sensor_id': '3', 'timestamp': 1772387584, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387585, 'water_temperature': 28.71988295727136, 'ph_level': 8.656097304917763, 'turbidity': 41.44, 'dissolved_oxygen': 7.96}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387585, 'p_class_0': 0.5, 'p_class_1': 0.5, 'pred': 0}
# Received: sensor_id:5,{'timestamp': 1772387585, 'water_temperature': 29.093224103997205, 'ph_level': 7.737907475587362, 'turbidity': 35.91, 'dissolved_oxygen': 11.39}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387585, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387585, 'water_temperature': 29.160407433715203, 'ph_level': 7.972674342114308, 'turbidity': 41.35, 'dissolved_oxygen': 6.09}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387585, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:6,{'timestamp': 1772387585, 'water_temperature': 29.2915335309813, 'ph_level': 8.21162509059186, 'turbidity': 41.84, 'dissolved_oxygen': 9.7}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387585, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387586, 'water_temperature': 30.005860151751033, 'ph_level': 8.540614560113623, 'turbidity': 7.24, 'dissolved_oxygen': 11.81}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387586, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387586, 'water_temperature': 29.047950113161775, 'ph_level': 7.849792479441962, 'turbidity': 26.71, 'dissolved_oxygen': 9.66}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387586, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:5,{'timestamp': 1772387586, 'water_temperature': 29.721567847959065, 'ph_level': 8.225591414753286, 'turbidity': 23.16, 'dissolved_oxygen': 9.89}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387586, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387586, 'water_temperature': 29.26073961799084, 'ph_level': 8.486103206471542, 'turbidity': 17.95, 'dissolved_oxygen': 8.24}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387586, 'p_class_0': 0.9, 'p_class_1': 0.1, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387587, 'water_temperature': 30.145928203552103, 'ph_level': 7.835218462688102, 'turbidity': 32.21, 'dissolved_oxygen': 6.95}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387587, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:2,{'timestamp': 1772387587, 'water_temperature': 28.985772053679057, 'ph_level': 8.428453134177808, 'turbidity': 23.18, 'dissolved_oxygen': 10.09}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387587, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387587, 'water_temperature': 30.355991531715553, 'ph_level': 8.14235160835792, 'turbidity': 16.03, 'dissolved_oxygen': 6.55}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387587, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:5,{'timestamp': 1772387587, 'water_temperature': 29.642016839456343, 'ph_level': 8.61971567748003, 'turbidity': 12.87, 'dissolved_oxygen': 11.88}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387587, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387588, 'water_temperature': 28.660403587077802, 'ph_level': 8.38227014710898, 'turbidity': 34.44, 'dissolved_oxygen': 10.95}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387588, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387588, 'water_temperature': 28.638903222160582, 'ph_level': 8.591104883486755, 'turbidity': 47.97, 'dissolved_oxygen': 6.73}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387588, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:5,{'timestamp': 1772387588, 'water_temperature': 29.373067607668197, 'ph_level': 8.088935862808405, 'turbidity': 21.1, 'dissolved_oxygen': 5.32}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387588, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:6,{'timestamp': 1772387588, 'water_temperature': 29.184439571934725, 'ph_level': 8.125903952097664, 'turbidity': 9.21, 'dissolved_oxygen': 10.07}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387588, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387588, 'water_temperature': 28.91122074591238, 'ph_level': 8.398465399449815, 'turbidity': 8.24, 'dissolved_oxygen': 6.27}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387588, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:2,{'timestamp': 1772387588, 'water_temperature': 29.87390629969407, 'ph_level': 7.797692983629914, 'turbidity': 13.23, 'dissolved_oxygen': 10.21}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387588, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387588, 'water_temperature': 29.594387431072935, 'ph_level': 8.33319232046188, 'turbidity': 43.25, 'dissolved_oxygen': 10.5}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387588, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:5,{'timestamp': 1772387588, 'water_temperature': 29.570359069950285, 'ph_level': 8.122703909562118, 'turbidity': 37.4, 'dissolved_oxygen': 10.63}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387588, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387589, 'water_temperature': 29.04637574321285, 'ph_level': 8.186478040962164, 'turbidity': 8.37, 'dissolved_oxygen': 7.92}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387589, 'p_class_0': 0.4, 'p_class_1': 0.6, 'pred': 1}
# Received: sensor_id:2,{'timestamp': 1772387589, 'water_temperature': 29.98880139308049, 'ph_level': 7.76448201897624, 'turbidity': 45.93, 'dissolved_oxygen': 11.83}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387589, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:5,{'timestamp': 1772387589, 'water_temperature': 29.614143075825524, 'ph_level': 8.634353856853272, 'turbidity': 31.15, 'dissolved_oxygen': 9.82}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387589, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387589, 'water_temperature': 28.527780736131984, 'ph_level': 8.599529474368218, 'turbidity': 31.85, 'dissolved_oxygen': 8.38}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387589, 'p_class_0': 0.4, 'p_class_1': 0.6, 'pred': 1}
# Received: sensor_id:0,{'timestamp': 1772387590, 'water_temperature': 29.436916593705174, 'ph_level': 8.471548636180408, 'turbidity': 6.58, 'dissolved_oxygen': 7.94}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387590, 'p_class_0': 0.8, 'p_class_1': 0.2, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387590, 'water_temperature': 30.387264268367833, 'ph_level': 8.270281038162963, 'turbidity': 37.03, 'dissolved_oxygen': 6.88}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387590, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:5,{'timestamp': 1772387590, 'water_temperature': 29.628152593794002, 'ph_level': 8.524120837813559, 'turbidity': 19.2, 'dissolved_oxygen': 10.38}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387590, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387590, 'water_temperature': 29.747038973996723, 'ph_level': 8.452273241366061, 'turbidity': 13.29, 'dissolved_oxygen': 7.43}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387590, 'p_class_0': 0.7, 'p_class_1': 0.3, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387591, 'water_temperature': 29.571176773445433, 'ph_level': 8.40999679077945, 'turbidity': 32.53, 'dissolved_oxygen': 10.29}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387591, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387591, 'water_temperature': 28.4499946448078, 'ph_level': 7.882803102539464, 'turbidity': 23.05, 'dissolved_oxygen': 7.13}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387591, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:6,{'timestamp': 1772387591, 'water_temperature': 29.15474177700104, 'ph_level': 8.08773713670275, 'turbidity': 14.5, 'dissolved_oxygen': 11.35}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387591, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:5,{'timestamp': 1772387591, 'water_temperature': 30.054400631009948, 'ph_level': 8.066878602919802, 'turbidity': 7.47, 'dissolved_oxygen': 5.33}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387591, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:0,{'timestamp': 1772387592, 'water_temperature': 30.211739636047316, 'ph_level': 7.988560221968887, 'turbidity': 48.84, 'dissolved_oxygen': 6.25}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387592, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:2,{'timestamp': 1772387592, 'water_temperature': 29.921644973586467, 'ph_level': 8.1429239254772, 'turbidity': 46.57, 'dissolved_oxygen': 7.55}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387592, 'p_class_0': 0.4, 'p_class_1': 0.6, 'pred': 1}
# Received: sensor_id:5,{'timestamp': 1772387592, 'water_temperature': 28.75044250499515, 'ph_level': 8.554318566543312, 'turbidity': 41.08, 'dissolved_oxygen': 9.8}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387592, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387592, 'water_temperature': 30.045675933145976, 'ph_level': 8.097106306250168, 'turbidity': 41.68, 'dissolved_oxygen': 9.96}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387592, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387593, 'water_temperature': 29.18451156646289, 'ph_level': 8.628258331414921, 'turbidity': 28.57, 'dissolved_oxygen': 11.74}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387593, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:5,{'timestamp': 1772387593, 'water_temperature': 29.76002907665066, 'ph_level': 8.6280987791159, 'turbidity': 22.69, 'dissolved_oxygen': 8.28}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387593, 'p_class_0': 0.9, 'p_class_1': 0.1, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387593, 'water_temperature': 28.797769928321124, 'ph_level': 8.280538922673028, 'turbidity': 22.54, 'dissolved_oxygen': 10.94}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387593, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387593, 'water_temperature': 30.32988343066962, 'ph_level': 7.953932219375869, 'turbidity': 31.26, 'dissolved_oxygen': 5.31}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387593, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:0,{'timestamp': 1772387594, 'water_temperature': 29.72864412055516, 'ph_level': 7.981989241556422, 'turbidity': 48.45, 'dissolved_oxygen': 6.97}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387594, 'p_class_0': 0.2, 'p_class_1': 0.8, 'pred': 1}
# Received: sensor_id:2,{'timestamp': 1772387594, 'water_temperature': 29.415092913420384, 'ph_level': 8.21931308491517, 'turbidity': 45.18, 'dissolved_oxygen': 9.6}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387594, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:5,{'timestamp': 1772387594, 'water_temperature': 29.861013037225806, 'ph_level': 8.412963760370372, 'turbidity': 50.0, 'dissolved_oxygen': 11.26}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387594, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387594, 'water_temperature': 28.95906399237151, 'ph_level': 7.7014414842499805, 'turbidity': 27.0, 'dissolved_oxygen': 7.12}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387594, 'p_class_0': 0.1, 'p_class_1': 0.9, 'pred': 1}
# Received: sensor_id:0,{'timestamp': 1772387595, 'water_temperature': 28.751840880055067, 'ph_level': 8.543592972413844, 'turbidity': 15.06, 'dissolved_oxygen': 11.01}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387595, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387595, 'water_temperature': 29.666215117995584, 'ph_level': 7.715438432966363, 'turbidity': 17.56, 'dissolved_oxygen': 6.48}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387595, 'p_class_0': 0.3, 'p_class_1': 0.7, 'pred': 1}
# Received: sensor_id:5,{'timestamp': 1772387595, 'water_temperature': 30.16199557142978, 'ph_level': 8.47117504402328, 'turbidity': 39.1, 'dissolved_oxygen': 8.67}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387595, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387595, 'water_temperature': 29.038213783005045, 'ph_level': 8.408519478958862, 'turbidity': 28.31, 'dissolved_oxygen': 10.92}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387595, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387596, 'water_temperature': 30.293190514904232, 'ph_level': 7.996856192805245, 'turbidity': 31.24, 'dissolved_oxygen': 10.24}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387596, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387596, 'water_temperature': 28.8738559424341, 'ph_level': 7.868174482615374, 'turbidity': 22.13, 'dissolved_oxygen': 5.3}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387596, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:5,{'timestamp': 1772387596, 'water_temperature': 28.457636675853717, 'ph_level': 8.514513872652476, 'turbidity': 28.56, 'dissolved_oxygen': 10.8}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387596, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387596, 'water_temperature': 29.853503774560235, 'ph_level': 8.586006321719742, 'turbidity': 49.22, 'dissolved_oxygen': 9.97}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387596, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387597, 'water_temperature': 29.49942538399393, 'ph_level': 7.84348028582485, 'turbidity': 34.63, 'dissolved_oxygen': 10.24}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387597, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387597, 'water_temperature': 29.517517009638713, 'ph_level': 8.449556726685472, 'turbidity': 29.22, 'dissolved_oxygen': 11.83}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387597, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:5,{'timestamp': 1772387597, 'water_temperature': 28.678866821025924, 'ph_level': 8.682595229632792, 'turbidity': 30.05, 'dissolved_oxygen': 10.81}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387597, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387597, 'water_temperature': 29.07778674735327, 'ph_level': 8.28314809815442, 'turbidity': 42.67, 'dissolved_oxygen': 6.0}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387597, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:0,{'timestamp': 1772387598, 'water_temperature': 29.32542097574271, 'ph_level': 8.583990702686735, 'turbidity': 40.23, 'dissolved_oxygen': 9.63}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387598, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387598, 'water_temperature': 30.423010715338425, 'ph_level': 8.071804919907054, 'turbidity': 39.02, 'dissolved_oxygen': 7.35}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387598, 'p_class_0': 0.1, 'p_class_1': 0.9, 'pred': 1}
# Received: sensor_id:5,{'timestamp': 1772387598, 'water_temperature': 29.848289815406414, 'ph_level': 8.579482276419395, 'turbidity': 40.65, 'dissolved_oxygen': 5.97}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387598, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:6,{'timestamp': 1772387598, 'water_temperature': 30.237188090684747, 'ph_level': 8.081879746715305, 'turbidity': 13.19, 'dissolved_oxygen': 9.32}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387598, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387599, 'water_temperature': 28.922415886329354, 'ph_level': 8.405342842480698, 'turbidity': 10.82, 'dissolved_oxygen': 11.55}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387599, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387599, 'water_temperature': 28.666057527644426, 'ph_level': 8.158840588486074, 'turbidity': 10.77, 'dissolved_oxygen': 5.05}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387599, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:6,{'timestamp': 1772387599, 'water_temperature': 28.94527619397362, 'ph_level': 8.009119707998817, 'turbidity': 42.35, 'dissolved_oxygen': 5.89}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387599, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:5,{'timestamp': 1772387599, 'water_temperature': 29.36090394121157, 'ph_level': 7.704069754263416, 'turbidity': 26.59, 'dissolved_oxygen': 8.11}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387599, 'p_class_0': 0.9, 'p_class_1': 0.1, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387600, 'water_temperature': 30.10407503698897, 'ph_level': 8.24741484252206, 'turbidity': 29.98, 'dissolved_oxygen': 10.46}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387600, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387600, 'water_temperature': 29.48152250475166, 'ph_level': 8.017276688567263, 'turbidity': 24.77, 'dissolved_oxygen': 6.59}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387600, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:5,{'timestamp': 1772387600, 'water_temperature': 29.50748141424922, 'ph_level': 7.791520877912806, 'turbidity': 17.49, 'dissolved_oxygen': 11.85}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387600, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387600, 'water_temperature': 29.920271883354182, 'ph_level': 7.922897937493507, 'turbidity': 7.22, 'dissolved_oxygen': 9.1}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387600, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387601, 'water_temperature': 30.278349802917408, 'ph_level': 8.282030243843309, 'turbidity': 5.53, 'dissolved_oxygen': 10.36}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387601, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387601, 'water_temperature': 30.190102493502696, 'ph_level': 8.119915871701275, 'turbidity': 30.23, 'dissolved_oxygen': 7.96}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387601, 'p_class_0': 0.5, 'p_class_1': 0.5, 'pred': 0}
# Received: sensor_id:5,{'timestamp': 1772387601, 'water_temperature': 29.13074441842911, 'ph_level': 7.943013137873973, 'turbidity': 17.01, 'dissolved_oxygen': 9.8}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387601, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387601, 'water_temperature': 28.657117602944922, 'ph_level': 7.752483314955278, 'turbidity': 42.72, 'dissolved_oxygen': 5.2}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387601, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:0,{'timestamp': 1772387602, 'water_temperature': 28.488994653150666, 'ph_level': 8.071961115845868, 'turbidity': 49.89, 'dissolved_oxygen': 11.47}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387602, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387602, 'water_temperature': 29.73134216990938, 'ph_level': 7.874426370021888, 'turbidity': 21.84, 'dissolved_oxygen': 6.76}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387602, 'p_class_0': 0.3, 'p_class_1': 0.7, 'pred': 1}
# Received: sensor_id:5,{'timestamp': 1772387602, 'water_temperature': 30.056899892152323, 'ph_level': 8.511559338149317, 'turbidity': 17.17, 'dissolved_oxygen': 7.83}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387602, 'p_class_0': 0.6, 'p_class_1': 0.4, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387602, 'water_temperature': 29.355085189789442, 'ph_level': 8.308963667183903, 'turbidity': 17.19, 'dissolved_oxygen': 10.82}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387602, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387603, 'water_temperature': 28.758401734211585, 'ph_level': 8.433114497074646, 'turbidity': 22.25, 'dissolved_oxygen': 11.67}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387603, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387603, 'water_temperature': 29.882027436086723, 'ph_level': 8.359299126855808, 'turbidity': 43.57, 'dissolved_oxygen': 8.98}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387603, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:5,{'timestamp': 1772387603, 'water_temperature': 29.837185397451606, 'ph_level': 7.929042857556486, 'turbidity': 45.53, 'dissolved_oxygen': 11.03}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387603, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387603, 'water_temperature': 28.988573557196, 'ph_level': 7.909902236269175, 'turbidity': 22.22, 'dissolved_oxygen': 9.35}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387603, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387604, 'water_temperature': 28.780370241464308, 'ph_level': 8.36459364399324, 'turbidity': 40.76, 'dissolved_oxygen': 5.82}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387604, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:2,{'timestamp': 1772387604, 'water_temperature': 29.127388602672646, 'ph_level': 8.434512962109158, 'turbidity': 39.25, 'dissolved_oxygen': 8.07}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387604, 'p_class_0': 0.7, 'p_class_1': 0.3, 'pred': 0}
# Received: sensor_id:5,{'timestamp': 1772387604, 'water_temperature': 28.563095509412758, 'ph_level': 8.366337379721152, 'turbidity': 9.14, 'dissolved_oxygen': 5.32}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387604, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:6,{'timestamp': 1772387604, 'water_temperature': 29.978245247561098, 'ph_level': 7.8217833900861615, 'turbidity': 41.63, 'dissolved_oxygen': 5.13}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387604, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:0,{'timestamp': 1772387605, 'water_temperature': 29.926931669744704, 'ph_level': 8.332493695514138, 'turbidity': 15.07, 'dissolved_oxygen': 11.92}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387605, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387605, 'water_temperature': 29.766769608550334, 'ph_level': 8.591771857476957, 'turbidity': 23.06, 'dissolved_oxygen': 7.91}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387605, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:5,{'timestamp': 1772387605, 'water_temperature': 30.23354462290969, 'ph_level': 8.470065387337243, 'turbidity': 41.88, 'dissolved_oxygen': 9.9}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387605, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387605, 'water_temperature': 29.616611985633654, 'ph_level': 8.031553577749705, 'turbidity': 13.82, 'dissolved_oxygen': 6.78}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387605, 'p_class_0': 0.1, 'p_class_1': 0.9, 'pred': 1}
# Received: sensor_id:0,{'timestamp': 1772387606, 'water_temperature': 29.62554757117867, 'ph_level': 7.911256868094793, 'turbidity': 42.99, 'dissolved_oxygen': 6.36}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387606, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:2,{'timestamp': 1772387606, 'water_temperature': 30.145689058364443, 'ph_level': 8.042278545912248, 'turbidity': 19.52, 'dissolved_oxygen': 10.99}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387606, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:5,{'timestamp': 1772387606, 'water_temperature': 30.00830892818623, 'ph_level': 7.758690967565347, 'turbidity': 19.81, 'dissolved_oxygen': 9.07}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387606, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387606, 'water_temperature': 30.034662193821305, 'ph_level': 8.048349526253771, 'turbidity': 20.38, 'dissolved_oxygen': 11.87}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387606, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387607, 'water_temperature': 29.542714796844074, 'ph_level': 8.221020345023605, 'turbidity': 41.6, 'dissolved_oxygen': 9.54}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387607, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:2,{'timestamp': 1772387607, 'water_temperature': 29.178018549943364, 'ph_level': 8.494890743022383, 'turbidity': 24.77, 'dissolved_oxygen': 7.04}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387607, 'p_class_0': 0.0, 'p_class_1': 1.0, 'pred': 1}
# Received: sensor_id:5,{'timestamp': 1772387607, 'water_temperature': 29.795108799311524, 'ph_level': 7.764679804264754, 'turbidity': 21.07, 'dissolved_oxygen': 9.43}
# Datos del proceso de aireación ML B del sensor 5: {'sensor_id': '5', 'timestamp': 1772387607, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:6,{'timestamp': 1772387607, 'water_temperature': 29.057495186435375, 'ph_level': 8.617695368328297, 'turbidity': 13.45, 'dissolved_oxygen': 11.75}
# Datos del proceso de aireación ML B del sensor 6: {'sensor_id': '6', 'timestamp': 1772387607, 'p_class_0': 1.0, 'p_class_1': 0.0, 'pred': 0}
# Received: sensor_id:0,{'timestamp': 1772387608, 'water_temperature': 30.284723444079525, 'ph_level': 8.456573558476656, 'turbidity': 48.59, 'dissolved_oxygen': 7.36}
# Datos del proceso de aireación ML B del sensor 0: {'sensor_id': '0', 'timestamp': 1772387608, 'p_class_0': 0.2, 'p_class_1': 0.8, 'pred': 1}
# Received: sensor_id:2,{'timestamp': 1772387608, 'water_temperature': 30.002876319625038, 'ph_level': 7.740255749351667, 'turbidity': 35.71, 'dissolved_oxygen': 5.95}
# Datos del proceso de aireación ML B del sensor 2: {'sensor_id': '2', 'timestamp': 1772387608, 'p_class_0': 0.1, 'p_class_1': 0.9, 'pred': 1}

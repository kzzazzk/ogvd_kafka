# %%
from kafka import KafkaProducer
import json
import time
import random
from math import cos, pi
import sys

# %%
def generate_sensor_data():
    timestamp = int(time.time())

    # Simulate IoT sensor data for water quality metrics with realistic patterns
    water_temperature = random.uniform(1, 3) + round(20 + 5 * (1 + 0.5 * (1 + cos((timestamp % 86400) / 86400 * 2 * pi))), 2)
    ph_level = random.uniform(0, 1) + round(7.5 + 0.2 * (1 + cos((timestamp % 86400) / 86400 * 2 * pi)), 2)
    turbidity = round(random.uniform(5, 50), 2)  # Turbidity in NTU (Nephelometric Turbidity Units)
    dissolved_oxygen = round(random.uniform(5, 12), 2)  # Dissolved Oxygen in mg/L

    return {
        "timestamp": timestamp,
        "water_temperature": water_temperature,
        "ph_level": ph_level,
        "turbidity": turbidity,
        "dissolved_oxygen": dissolved_oxygen
    }

# %%
 # Kafka configuration
kafka_topic = "water_quality"
kafka_bootstrap_servers = ["localhost:9092"] 

# Create Kafka producer
producer_number = 7
producers = []
producer_ids = []
# Create Kafka producer
for i in range(producer_number):
    producer_ids.append(str(i))
    producers.append(KafkaProducer(
    bootstrap_servers=kafka_bootstrap_servers,
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
    ))
print(f"Producing messages to Kafka topic '{kafka_topic}'...")

try:
    while True:
        # Generate sensor data
        for i in range(producer_number):
            # Generate sensor data
            sensor_data = generate_sensor_data()
            # Publish sensor data to Kafka
            producers[i].send(kafka_topic,
            key=producer_ids[i].encode('utf-8'),value=sensor_data)
            print(f"Sent{producer_ids[i]}, {sensor_data}")

        # Wait for 1 second
        time.sleep(1)
except KeyboardInterrupt:
    print("Stopped producing messages.")
finally:
    producer.close()
# Out:
# Producing messages to Kafka topic 'water_quality'...
# Sent0, {'timestamp': 1772380458, 'water_temperature': 28.19428709669517, 'ph_level': 8.302399820202822, 'turbidity': 7.59, 'dissolved_oxygen': 7.55}
# Sent1, {'timestamp': 1772380458, 'water_temperature': 27.47295157335033, 'ph_level': 7.916441828829642, 'turbidity': 45.41, 'dissolved_oxygen': 11.12}
# Sent2, {'timestamp': 1772380458, 'water_temperature': 28.701633710965186, 'ph_level': 8.007479104061098, 'turbidity': 24.82, 'dissolved_oxygen': 7.8}
# Sent3, {'timestamp': 1772380458, 'water_temperature': 27.535877663441497, 'ph_level': 8.491354879900813, 'turbidity': 5.38, 'dissolved_oxygen': 9.31}
# Sent4, {'timestamp': 1772380458, 'water_temperature': 29.056009822172637, 'ph_level': 8.58122364684338, 'turbidity': 21.08, 'dissolved_oxygen': 6.08}
# Sent5, {'timestamp': 1772380458, 'water_temperature': 28.761516765350336, 'ph_level': 7.871768771676615, 'turbidity': 34.33, 'dissolved_oxygen': 8.81}
# Sent6, {'timestamp': 1772380458, 'water_temperature': 27.80384144273563, 'ph_level': 8.249078452995846, 'turbidity': 30.45, 'dissolved_oxygen': 10.28}
# Sent0, {'timestamp': 1772380459, 'water_temperature': 28.398886523000467, 'ph_level': 8.239188481733171, 'turbidity': 7.94, 'dissolved_oxygen': 9.78}
# Sent1, {'timestamp': 1772380459, 'water_temperature': 28.129857973886487, 'ph_level': 8.063399318132557, 'turbidity': 42.33, 'dissolved_oxygen': 9.88}
# Sent2, {'timestamp': 1772380459, 'water_temperature': 27.88738762555696, 'ph_level': 8.115822171167157, 'turbidity': 9.83, 'dissolved_oxygen': 11.67}
# Sent3, {'timestamp': 1772380459, 'water_temperature': 28.16033169730968, 'ph_level': 8.382921141371902, 'turbidity': 34.14, 'dissolved_oxygen': 9.43}
# Sent4, {'timestamp': 1772380459, 'water_temperature': 27.28134346100356, 'ph_level': 7.911304984442733, 'turbidity': 25.88, 'dissolved_oxygen': 6.61}
# Sent5, {'timestamp': 1772380459, 'water_temperature': 28.196848379694607, 'ph_level': 8.342092661536217, 'turbidity': 45.91, 'dissolved_oxygen': 7.81}
# Sent6, {'timestamp': 1772380459, 'water_temperature': 28.598930866258858, 'ph_level': 7.613380777446125, 'turbidity': 47.05, 'dissolved_oxygen': 8.01}
# Sent0, {'timestamp': 1772380460, 'water_temperature': 27.846671750807662, 'ph_level': 7.895728081531864, 'turbidity': 40.67, 'dissolved_oxygen': 6.03}
# Sent1, {'timestamp': 1772380460, 'water_temperature': 28.711989361842534, 'ph_level': 8.357476705466375, 'turbidity': 32.04, 'dissolved_oxygen': 9.37}
# Sent2, {'timestamp': 1772380460, 'water_temperature': 28.328954611321283, 'ph_level': 8.555661312489303, 'turbidity': 15.7, 'dissolved_oxygen': 10.02}
# Sent3, {'timestamp': 1772380460, 'water_temperature': 28.03708355041435, 'ph_level': 8.106145001401762, 'turbidity': 28.55, 'dissolved_oxygen': 5.05}
# Sent4, {'timestamp': 1772380460, 'water_temperature': 28.430334370680647, 'ph_level': 7.960518141612679, 'turbidity': 29.29, 'dissolved_oxygen': 8.66}
# Sent5, {'timestamp': 1772380460, 'water_temperature': 28.027964348355454, 'ph_level': 8.469902439503052, 'turbidity': 10.1, 'dissolved_oxygen': 7.56}
# Sent6, {'timestamp': 1772380460, 'water_temperature': 28.36409453633108, 'ph_level': 7.853036525490673, 'turbidity': 24.47, 'dissolved_oxygen': 9.74}
# Sent0, {'timestamp': 1772380461, 'water_temperature': 28.409557074644574, 'ph_level': 8.039892191209855, 'turbidity': 15.02, 'dissolved_oxygen': 6.35}
# Sent1, {'timestamp': 1772380461, 'water_temperature': 29.156028589338888, 'ph_level': 8.385809704101321, 'turbidity': 15.96, 'dissolved_oxygen': 5.78}
# Sent2, {'timestamp': 1772380461, 'water_temperature': 27.508082040476847, 'ph_level': 8.342546132168035, 'turbidity': 16.29, 'dissolved_oxygen': 9.24}
# Sent3, {'timestamp': 1772380461, 'water_temperature': 29.07198993135622, 'ph_level': 7.73306198720907, 'turbidity': 46.66, 'dissolved_oxygen': 9.74}
# Sent4, {'timestamp': 1772380461, 'water_temperature': 27.360331674931615, 'ph_level': 7.756618685701418, 'turbidity': 40.51, 'dissolved_oxygen': 9.84}
# Sent5, {'timestamp': 1772380461, 'water_temperature': 28.43436854049287, 'ph_level': 7.746959815091228, 'turbidity': 39.09, 'dissolved_oxygen': 11.04}
# Sent6, {'timestamp': 1772380461, 'water_temperature': 28.434069903033333, 'ph_level': 8.071847965335095, 'turbidity': 35.65, 'dissolved_oxygen': 9.87}
# Sent0, {'timestamp': 1772380462, 'water_temperature': 27.224272085967623, 'ph_level': 8.237210889445652, 'turbidity': 38.96, 'dissolved_oxygen': 10.3}
# Sent1, {'timestamp': 1772380462, 'water_temperature': 28.972186881411737, 'ph_level': 7.689596402918285, 'turbidity': 31.38, 'dissolved_oxygen': 9.36}
# Sent2, {'timestamp': 1772380462, 'water_temperature': 27.49489694903685, 'ph_level': 8.35789495134568, 'turbidity': 39.87, 'dissolved_oxygen': 12.0}
# Sent3, {'timestamp': 1772380462, 'water_temperature': 28.431210329516823, 'ph_level': 7.718127924831776, 'turbidity': 6.76, 'dissolved_oxygen': 9.49}
# Sent4, {'timestamp': 1772380462, 'water_temperature': 27.430602294239023, 'ph_level': 7.776781144970748, 'turbidity': 43.6, 'dissolved_oxygen': 8.47}
# Sent5, {'timestamp': 1772380462, 'water_temperature': 28.343198294500226, 'ph_level': 7.861118296769031, 'turbidity': 10.04, 'dissolved_oxygen': 11.89}
# Sent6, {'timestamp': 1772380462, 'water_temperature': 28.420593458463465, 'ph_level': 8.326342285266591, 'turbidity': 21.5, 'dissolved_oxygen': 6.0}
# Sent0, {'timestamp': 1772380463, 'water_temperature': 27.366669152751015, 'ph_level': 8.455385608618414, 'turbidity': 36.97, 'dissolved_oxygen': 9.14}
# Sent1, {'timestamp': 1772380463, 'water_temperature': 27.90406032847338, 'ph_level': 7.731632424748873, 'turbidity': 49.58, 'dissolved_oxygen': 6.66}
# Sent2, {'timestamp': 1772380463, 'water_temperature': 27.403025361785758, 'ph_level': 8.467695915335975, 'turbidity': 48.7, 'dissolved_oxygen': 7.03}
# Sent3, {'timestamp': 1772380463, 'water_temperature': 27.582257084295527, 'ph_level': 8.14972441118458, 'turbidity': 47.53, 'dissolved_oxygen': 5.48}
# Sent4, {'timestamp': 1772380463, 'water_temperature': 28.435697952795582, 'ph_level': 7.641561641178493, 'turbidity': 13.74, 'dissolved_oxygen': 11.51}
# Sent5, {'timestamp': 1772380463, 'water_temperature': 28.871214511023823, 'ph_level': 8.452677058504985, 'turbidity': 5.03, 'dissolved_oxygen': 6.71}
# Sent6, {'timestamp': 1772380463, 'water_temperature': 27.790429945420037, 'ph_level': 7.689078636473444, 'turbidity': 7.72, 'dissolved_oxygen': 7.51}
# Sent0, {'timestamp': 1772380464, 'water_temperature': 28.12141676144563, 'ph_level': 8.517862316608273, 'turbidity': 23.73, 'dissolved_oxygen': 10.14}
# Sent1, {'timestamp': 1772380464, 'water_temperature': 27.2888621204944, 'ph_level': 8.237993075377787, 'turbidity': 25.79, 'dissolved_oxygen': 6.24}
# Sent2, {'timestamp': 1772380464, 'water_temperature': 28.629957503697405, 'ph_level': 7.82050953603969, 'turbidity': 30.42, 'dissolved_oxygen': 7.23}
# Sent3, {'timestamp': 1772380464, 'water_temperature': 27.85075397255981, 'ph_level': 7.989015627836188, 'turbidity': 7.12, 'dissolved_oxygen': 8.3}
# Sent4, {'timestamp': 1772380464, 'water_temperature': 27.943739868076538, 'ph_level': 8.418325609685699, 'turbidity': 31.4, 'dissolved_oxygen': 7.05}
# Sent5, {'timestamp': 1772380464, 'water_temperature': 28.885924630544274, 'ph_level': 7.928712743193699, 'turbidity': 30.34, 'dissolved_oxygen': 5.45}
# Sent6, {'timestamp': 1772380464, 'water_temperature': 29.04436929178561, 'ph_level': 7.7296098744745825, 'turbidity': 44.91, 'dissolved_oxygen': 7.59}
# Sent0, {'timestamp': 1772380465, 'water_temperature': 27.815322723957436, 'ph_level': 8.414331785880844, 'turbidity': 45.63, 'dissolved_oxygen': 5.91}
# Sent1, {'timestamp': 1772380465, 'water_temperature': 27.482534578542975, 'ph_level': 7.8323926401696955, 'turbidity': 18.01, 'dissolved_oxygen': 8.73}
# Sent2, {'timestamp': 1772380465, 'water_temperature': 28.552111125428507, 'ph_level': 8.22666122421399, 'turbidity': 30.94, 'dissolved_oxygen': 7.95}
# Sent3, {'timestamp': 1772380465, 'water_temperature': 28.930894544187225, 'ph_level': 8.377144078790348, 'turbidity': 14.16, 'dissolved_oxygen': 5.91}
# Sent4, {'timestamp': 1772380465, 'water_temperature': 28.200088133172066, 'ph_level': 8.353576072055569, 'turbidity': 15.17, 'dissolved_oxygen': 6.4}
# Sent5, {'timestamp': 1772380465, 'water_temperature': 27.287815092325513, 'ph_level': 7.896709393210625, 'turbidity': 24.0, 'dissolved_oxygen': 8.81}
# Sent6, {'timestamp': 1772380465, 'water_temperature': 27.849749856139923, 'ph_level': 7.6377493050072145, 'turbidity': 28.16, 'dissolved_oxygen': 8.63}
# Sent0, {'timestamp': 1772380466, 'water_temperature': 28.502195037806032, 'ph_level': 7.73628088920328, 'turbidity': 6.29, 'dissolved_oxygen': 11.08}
# Sent1, {'timestamp': 1772380466, 'water_temperature': 28.007979038976323, 'ph_level': 8.095415085341248, 'turbidity': 48.84, 'dissolved_oxygen': 7.64}
# Sent2, {'timestamp': 1772380466, 'water_temperature': 28.99739282546365, 'ph_level': 8.186324604978466, 'turbidity': 16.75, 'dissolved_oxygen': 5.77}
# Sent3, {'timestamp': 1772380466, 'water_temperature': 28.966630653601086, 'ph_level': 8.084197250136809, 'turbidity': 29.86, 'dissolved_oxygen': 10.15}
# Sent4, {'timestamp': 1772380466, 'water_temperature': 28.221794711487703, 'ph_level': 8.507293982194021, 'turbidity': 14.12, 'dissolved_oxygen': 8.02}
# Sent5, {'timestamp': 1772380466, 'water_temperature': 28.77138693550677, 'ph_level': 8.522017255251589, 'turbidity': 38.49, 'dissolved_oxygen': 8.07}
# Sent6, {'timestamp': 1772380466, 'water_temperature': 28.990430908648484, 'ph_level': 7.929200854269129, 'turbidity': 36.9, 'dissolved_oxygen': 8.74}
# Sent0, {'timestamp': 1772380466, 'water_temperature': 27.279540111067845, 'ph_level': 8.561465290207575, 'turbidity': 25.66, 'dissolved_oxygen': 6.42}
# Sent1, {'timestamp': 1772380466, 'water_temperature': 27.440745405613345, 'ph_level': 8.052471362722304, 'turbidity': 32.55, 'dissolved_oxygen': 9.02}
# Sent2, {'timestamp': 1772380466, 'water_temperature': 28.733455760439842, 'ph_level': 7.93480981883924, 'turbidity': 32.41, 'dissolved_oxygen': 10.0}
# Sent3, {'timestamp': 1772380466, 'water_temperature': 28.73371422076515, 'ph_level': 8.28366663269042, 'turbidity': 28.39, 'dissolved_oxygen': 5.55}
# Sent4, {'timestamp': 1772380466, 'water_temperature': 28.22072257391851, 'ph_level': 7.973320094186946, 'turbidity': 41.25, 'dissolved_oxygen': 10.73}
# Sent5, {'timestamp': 1772380466, 'water_temperature': 27.622385038805024, 'ph_level': 8.157469742895593, 'turbidity': 38.34, 'dissolved_oxygen': 6.3}
# Sent6, {'timestamp': 1772380466, 'water_temperature': 28.948702667054924, 'ph_level': 8.334884453911917, 'turbidity': 8.66, 'dissolved_oxygen': 10.03}
# Sent0, {'timestamp': 1772380467, 'water_temperature': 28.72244563342789, 'ph_level': 7.641596534426815, 'turbidity': 27.38, 'dissolved_oxygen': 8.53}
# Sent1, {'timestamp': 1772380467, 'water_temperature': 28.179064795538388, 'ph_level': 7.6160996407585575, 'turbidity': 16.84, 'dissolved_oxygen': 8.24}
# Sent2, {'timestamp': 1772380467, 'water_temperature': 27.225202180412428, 'ph_level': 7.638057753904928, 'turbidity': 19.09, 'dissolved_oxygen': 6.18}
# Sent3, {'timestamp': 1772380467, 'water_temperature': 27.349983958619653, 'ph_level': 8.295714487739518, 'turbidity': 16.06, 'dissolved_oxygen': 7.01}
# Sent4, {'timestamp': 1772380467, 'water_temperature': 28.72467810280114, 'ph_level': 7.824721066972887, 'turbidity': 12.28, 'dissolved_oxygen': 9.15}
# Sent5, {'timestamp': 1772380467, 'water_temperature': 27.267808583285735, 'ph_level': 8.479759040593263, 'turbidity': 14.09, 'dissolved_oxygen': 10.5}
# Sent6, {'timestamp': 1772380467, 'water_temperature': 28.905883950949548, 'ph_level': 7.8474419677567795, 'turbidity': 21.82, 'dissolved_oxygen': 8.5}
# Sent0, {'timestamp': 1772380468, 'water_temperature': 27.29089978266539, 'ph_level': 8.121001572280377, 'turbidity': 33.33, 'dissolved_oxygen': 11.65}
# Sent1, {'timestamp': 1772380468, 'water_temperature': 28.478164637597175, 'ph_level': 7.908965561944977, 'turbidity': 40.78, 'dissolved_oxygen': 8.55}
# Sent2, {'timestamp': 1772380468, 'water_temperature': 28.335905394144433, 'ph_level': 8.141637722210529, 'turbidity': 49.78, 'dissolved_oxygen': 6.56}
# Sent3, {'timestamp': 1772380468, 'water_temperature': 28.52723361127232, 'ph_level': 8.486186294332905, 'turbidity': 7.66, 'dissolved_oxygen': 7.56}
# Sent4, {'timestamp': 1772380468, 'water_temperature': 27.23103538936786, 'ph_level': 8.097962563220756, 'turbidity': 20.61, 'dissolved_oxygen': 10.9}
# Sent5, {'timestamp': 1772380468, 'water_temperature': 28.673841143827847, 'ph_level': 8.284125793178399, 'turbidity': 18.26, 'dissolved_oxygen': 10.75}
# Sent6, {'timestamp': 1772380468, 'water_temperature': 28.935357058802087, 'ph_level': 8.446531705823684, 'turbidity': 39.38, 'dissolved_oxygen': 11.08}
# Sent0, {'timestamp': 1772380469, 'water_temperature': 28.017718125861943, 'ph_level': 8.542037415998168, 'turbidity': 21.15, 'dissolved_oxygen': 5.57}
# Sent1, {'timestamp': 1772380469, 'water_temperature': 27.643547041356737, 'ph_level': 7.791228681538448, 'turbidity': 8.21, 'dissolved_oxygen': 10.02}
# Sent2, {'timestamp': 1772380469, 'water_temperature': 28.028555931231924, 'ph_level': 8.036602803137379, 'turbidity': 43.2, 'dissolved_oxygen': 6.52}
# Sent3, {'timestamp': 1772380469, 'water_temperature': 27.55207609341525, 'ph_level': 7.6682122451517785, 'turbidity': 47.84, 'dissolved_oxygen': 8.6}
# Sent4, {'timestamp': 1772380469, 'water_temperature': 27.99741549304733, 'ph_level': 8.541559889990234, 'turbidity': 32.76, 'dissolved_oxygen': 5.17}
# Sent5, {'timestamp': 1772380469, 'water_temperature': 27.608326474894422, 'ph_level': 8.570755930969518, 'turbidity': 46.62, 'dissolved_oxygen': 10.58}
# Sent6, {'timestamp': 1772380469, 'water_temperature': 28.115514747515284, 'ph_level': 7.616757644507824, 'turbidity': 16.07, 'dissolved_oxygen': 8.45}
# Sent0, {'timestamp': 1772380470, 'water_temperature': 28.038267782254476, 'ph_level': 8.229228630603751, 'turbidity': 20.36, 'dissolved_oxygen': 10.68}
# Sent1, {'timestamp': 1772380470, 'water_temperature': 28.707601705903496, 'ph_level': 8.249964264272267, 'turbidity': 44.58, 'dissolved_oxygen': 9.61}
# Sent2, {'timestamp': 1772380470, 'water_temperature': 28.408496381261806, 'ph_level': 8.374112518783752, 'turbidity': 13.86, 'dissolved_oxygen': 11.33}
# Sent3, {'timestamp': 1772380470, 'water_temperature': 28.06912097191106, 'ph_level': 7.729653786017967, 'turbidity': 28.95, 'dissolved_oxygen': 6.32}
# Sent4, {'timestamp': 1772380470, 'water_temperature': 27.999513870691743, 'ph_level': 8.443264688712846, 'turbidity': 42.96, 'dissolved_oxygen': 9.8}
# Sent5, {'timestamp': 1772380470, 'water_temperature': 28.532257695476233, 'ph_level': 7.901112000756395, 'turbidity': 49.52, 'dissolved_oxygen': 11.52}
# Sent6, {'timestamp': 1772380470, 'water_temperature': 27.878535696553133, 'ph_level': 8.4961687919797, 'turbidity': 36.69, 'dissolved_oxygen': 6.19}
# Sent0, {'timestamp': 1772380471, 'water_temperature': 28.819867791368807, 'ph_level': 8.517280788165637, 'turbidity': 33.35, 'dissolved_oxygen': 6.21}
# Sent1, {'timestamp': 1772380471, 'water_temperature': 28.36768748909158, 'ph_level': 7.656411058090226, 'turbidity': 34.55, 'dissolved_oxygen': 10.05}
# Sent2, {'timestamp': 1772380471, 'water_temperature': 27.744714534356124, 'ph_level': 7.781207470844151, 'turbidity': 49.49, 'dissolved_oxygen': 6.07}
# Sent3, {'timestamp': 1772380471, 'water_temperature': 28.29578859926675, 'ph_level': 8.596501952388447, 'turbidity': 30.54, 'dissolved_oxygen': 5.46}
# Sent4, {'timestamp': 1772380471, 'water_temperature': 27.228505650370277, 'ph_level': 7.916312385074113, 'turbidity': 35.23, 'dissolved_oxygen': 6.24}
# Sent5, {'timestamp': 1772380471, 'water_temperature': 27.987880581284944, 'ph_level': 8.488963131250943, 'turbidity': 19.32, 'dissolved_oxygen': 9.52}
# Sent6, {'timestamp': 1772380471, 'water_temperature': 27.872694814834567, 'ph_level': 8.14768733397797, 'turbidity': 22.47, 'dissolved_oxygen': 6.58}
# Sent0, {'timestamp': 1772380472, 'water_temperature': 28.586492484069332, 'ph_level': 7.693317310152343, 'turbidity': 33.07, 'dissolved_oxygen': 10.7}
# Sent1, {'timestamp': 1772380472, 'water_temperature': 27.60649256795678, 'ph_level': 8.382386818942948, 'turbidity': 11.57, 'dissolved_oxygen': 11.18}
# Sent2, {'timestamp': 1772380472, 'water_temperature': 27.931635269217047, 'ph_level': 8.05591094468405, 'turbidity': 21.84, 'dissolved_oxygen': 11.46}
# Sent3, {'timestamp': 1772380472, 'water_temperature': 29.137261350974384, 'ph_level': 8.408823907346932, 'turbidity': 20.35, 'dissolved_oxygen': 10.45}
# Sent4, {'timestamp': 1772380472, 'water_temperature': 28.564014165417436, 'ph_level': 7.707785208812104, 'turbidity': 48.35, 'dissolved_oxygen': 6.1}
# Sent5, {'timestamp': 1772380472, 'water_temperature': 27.921080037466222, 'ph_level': 8.014882786936647, 'turbidity': 45.87, 'dissolved_oxygen': 9.5}
# Sent6, {'timestamp': 1772380472, 'water_temperature': 28.500979059041796, 'ph_level': 8.448219281197572, 'turbidity': 37.28, 'dissolved_oxygen': 5.3}
# Stopped producing messages.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 34
#      32    print("Stopped producing messages.")
#      33 finally:
# ---> 34    producer.close()
#
# NameError: name 'producer' is not defined
